# %%
import torch
import math
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms
import torch.nn.functional as F
import time
import os
import torch.backends.cudnn as cudnn

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = '0'                # GPU Number 
start_time = time.time()
batch_size = 64
learning_rate = 0.1
root_dir = 'D:\Deeplearning/cifar10/'
default_directory = 'D:\Deeplearning/save_models'

# %%
# Data Augmentation
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),               # Random Position Crop
    transforms.RandomHorizontalFlip(),                  # right and left flip
    transforms.ToTensor(),                              # change [0,255] Int value to [0,1] Float value
    transforms.Normalize(mean=(0.4914, 0.4824, 0.4467), # RGB Normalize MEAN
                         std=(0.2471, 0.2436, 0.2616))  # RGB Normalize Standard Deviation
])

transform_test = transforms.Compose([
    transforms.ToTensor(),                              # change [0,255] Int value to [0,1] Float value
    transforms.Normalize(mean=(0.4914, 0.4824, 0.4467), # RGB Normalize MEAN
                         std=(0.2471, 0.2436, 0.2616))  # RGB Normalize Standard Deviation
])

# %%
# automatically download
train_dataset = datasets.CIFAR10(root=root_dir,
                                 train=True,
                                 transform=transform_train,
                                 download=True)

test_dataset = datasets.CIFAR10(root=root_dir,
                                train=False,
                                transform=transform_test)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True,            # at Training Procedure, Data Shuffle = True
                                           num_workers=4)           # CPU loader number

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False,            # at Test Procedure, Data Shuffle = False
                                          num_workers=4)            # CPU loader number
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to D:\Deeplearning/cifar10/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting D:\Deeplearning/cifar10/cifar-10-python.tar.gz to D:\Deeplearning/cifar10/

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = out + self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
model = ResNet(BasicBlock, [2, 2, 2, 2])
optimizer = optim.SGD(model.parameters(), learning_rate,
                                momentum=0.9,
                                weight_decay=1e-4,
                                nesterov=True)
criterion = nn.CrossEntropyLoss()

if torch.cuda.device_count() > 0:
    print("USE", torch.cuda.device_count(), "GPUs!")
    model = nn.DataParallel(model).cuda()
    cudnn.benchmark = True
else:
    print("USE ONLY CPU!")
# Out:
# USE 1 GPUs!

# %%
def train(epoch):
    model.train()
    train_loss = 0 
    total = 0
    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        if torch.cuda.is_available():
            data, target = Variable(data.cuda()), Variable(target.cuda())
        else:
            data, target = Variable(data), Variable(target)

        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(output.data, 1)

        total += target.size(0)
        correct += predicted.eq(target.data).cpu().sum()
        if batch_idx % 10 == 0:
            print('Epoch: {} | Batch_idx: {} |  Loss: ({:.4f}) | Acc: ({:.2f}%) ({}/{})'
                  .format(epoch, batch_idx, train_loss / (batch_idx + 1), 100. * correct / total, correct, total))

# %%
def test():
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        if torch.cuda.is_available():
            data, target = Variable(data.cuda()), Variable(target.cuda())
        else:
            data, target = Variable(data), Variable(target)

        outputs = model(data)
        loss = criterion(outputs, target)

        test_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += target.size(0)
        correct += predicted.eq(target.data).cpu().sum()
    print('# TEST : Loss: ({:.4f}) | Acc: ({:.2f}%) ({}/{})'
          .format(test_loss / (batch_idx + 1), 100. * correct / total, correct, total))

# %%
def save_checkpoint(directory, state, filename='latest.tar.gz'):

    if not os.path.exists(directory):
        os.makedirs(directory)

    model_filename = os.path.join(directory, filename)
    torch.save(state, model_filename)
    print("=> saving checkpoint")

# %%
def load_checkpoint(directory, filename='latest.tar.gz'):

    model_filename = os.path.join(directory, filename)
    if os.path.exists(model_filename):
        print("=> loading checkpoint")
        state = torch.load(model_filename)
        return state
    else:
        return None

# %%
start_epoch = 0

checkpoint = load_checkpoint(default_directory)
if not checkpoint:
    pass
else:
    start_epoch = checkpoint['epoch'] + 1
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])

# %%
for epoch in range(start_epoch, 165):

    if epoch < 80:
        lr = learning_rate
    elif epoch < 120:
        lr = learning_rate * 0.1
    else:
        lr = learning_rate * 0.01
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

    train(epoch)
    save_checkpoint(default_directory, {
        'epoch': epoch,
        'model': model,
        'state_dict': model.state_dict(),
        'optimizer': optimizer.state_dict(),
    })
    test()  

now = time.gmtime(time.time() - start_time)
print('{} hours {} mins {} secs for training'.format(now.tm_hour, now.tm_min, now.tm_sec))
# Out:
# Epoch: 0 | Batch_idx: 0 |  Loss: (2.4529) | Acc: (10.94%) (7/64)
# Epoch: 0 | Batch_idx: 10 |  Loss: (14.9879) | Acc: (9.09%) (64/704)
# Epoch: 0 | Batch_idx: 20 |  Loss: (9.7690) | Acc: (9.45%) (127/1344)
# Epoch: 0 | Batch_idx: 30 |  Loss: (7.4156) | Acc: (9.68%) (192/1984)
# Epoch: 0 | Batch_idx: 40 |  Loss: (6.1711) | Acc: (9.72%) (255/2624)
# Epoch: 0 | Batch_idx: 50 |  Loss: (5.4191) | Acc: (9.83%) (321/3264)
# Epoch: 0 | Batch_idx: 60 |  Loss: (4.9120) | Acc: (10.30%) (402/3904)
# Epoch: 0 | Batch_idx: 70 |  Loss: (4.5409) | Acc: (10.85%) (493/4544)
# Epoch: 0 | Batch_idx: 80 |  Loss: (4.2619) | Acc: (11.28%) (585/5184)
# Epoch: 0 | Batch_idx: 90 |  Loss: (4.0416) | Acc: (11.49%) (669/5824)
# Epoch: 0 | Batch_idx: 100 |  Loss: (3.8631) | Acc: (11.96%) (773/6464)
# Epoch: 0 | Batch_idx: 110 |  Loss: (3.7129) | Acc: (12.51%) (889/7104)
# Epoch: 0 | Batch_idx: 120 |  Loss: (3.5872) | Acc: (12.85%) (995/7744)
# Epoch: 0 | Batch_idx: 130 |  Loss: (3.4767) | Acc: (13.36%) (1120/8384)
# Epoch: 0 | Batch_idx: 140 |  Loss: (3.3789) | Acc: (13.94%) (1258/9024)
# Epoch: 0 | Batch_idx: 150 |  Loss: (3.2944) | Acc: (14.25%) (1377/9664)
# Epoch: 0 | Batch_idx: 160 |  Loss: (3.2219) | Acc: (14.69%) (1514/10304)
# Epoch: 0 | Batch_idx: 170 |  Loss: (3.1523) | Acc: (15.12%) (1655/10944)
# Epoch: 0 | Batch_idx: 180 |  Loss: (3.0908) | Acc: (15.54%) (1800/11584)
# Epoch: 0 | Batch_idx: 190 |  Loss: (3.0318) | Acc: (15.92%) (1946/12224)
# Epoch: 0 | Batch_idx: 200 |  Loss: (2.9784) | Acc: (16.37%) (2106/12864)
# Epoch: 0 | Batch_idx: 210 |  Loss: (2.9330) | Acc: (16.82%) (2271/13504)
# Epoch: 0 | Batch_idx: 220 |  Loss: (2.8863) | Acc: (17.38%) (2458/14144)
# Epoch: 0 | Batch_idx: 230 |  Loss: (2.8472) | Acc: (17.71%) (2618/14784)
# Epoch: 0 | Batch_idx: 240 |  Loss: (2.8090) | Acc: (18.12%) (2795/15424)
# Epoch: 0 | Batch_idx: 250 |  Loss: (2.7734) | Acc: (18.46%) (2966/16064)
# Epoch: 0 | Batch_idx: 260 |  Loss: (2.7411) | Acc: (18.71%) (3125/16704)
# Epoch: 0 | Batch_idx: 270 |  Loss: (2.7088) | Acc: (19.19%) (3328/17344)
# Epoch: 0 | Batch_idx: 280 |  Loss: (2.6786) | Acc: (19.56%) (3518/17984)
# Epoch: 0 | Batch_idx: 290 |  Loss: (2.6513) | Acc: (19.82%) (3691/18624)
# Epoch: 0 | Batch_idx: 300 |  Loss: (2.6241) | Acc: (20.18%) (3887/19264)
# Epoch: 0 | Batch_idx: 310 |  Loss: (2.5988) | Acc: (20.48%) (4077/19904)
# Epoch: 0 | Batch_idx: 320 |  Loss: (2.5743) | Acc: (20.73%) (4259/20544)
# Epoch: 0 | Batch_idx: 330 |  Loss: (2.5511) | Acc: (21.04%) (4458/21184)
# Epoch: 0 | Batch_idx: 340 |  Loss: (2.5301) | Acc: (21.30%) (4648/21824)
# Epoch: 0 | Batch_idx: 350 |  Loss: (2.5067) | Acc: (21.60%) (4852/22464)
# Epoch: 0 | Batch_idx: 360 |  Loss: (2.4863) | Acc: (21.90%) (5060/23104)
# Epoch: 0 | Batch_idx: 370 |  Loss: (2.4676) | Acc: (22.21%) (5273/23744)
# Epoch: 0 | Batch_idx: 380 |  Loss: (2.4493) | Acc: (22.45%) (5475/24384)
# Epoch: 0 | Batch_idx: 390 |  Loss: (2.4292) | Acc: (22.76%) (5696/25024)
# Epoch: 0 | Batch_idx: 400 |  Loss: (2.4130) | Acc: (23.01%) (5906/25664)
# Epoch: 0 | Batch_idx: 410 |  Loss: (2.3960) | Acc: (23.26%) (6118/26304)
# Epoch: 0 | Batch_idx: 420 |  Loss: (2.3795) | Acc: (23.59%) (6355/26944)
# Epoch: 0 | Batch_idx: 430 |  Loss: (2.3650) | Acc: (23.81%) (6567/27584)
# Epoch: 0 | Batch_idx: 440 |  Loss: (2.3504) | Acc: (24.07%) (6793/28224)
# Epoch: 0 | Batch_idx: 450 |  Loss: (2.3371) | Acc: (24.33%) (7023/28864)
# Epoch: 0 | Batch_idx: 460 |  Loss: (2.3228) | Acc: (24.57%) (7250/29504)
# Epoch: 0 | Batch_idx: 470 |  Loss: (2.3115) | Acc: (24.71%) (7448/30144)
# Epoch: 0 | Batch_idx: 480 |  Loss: (2.2982) | Acc: (24.99%) (7694/30784)
# Epoch: 0 | Batch_idx: 490 |  Loss: (2.2860) | Acc: (25.21%) (7921/31424)
# Epoch: 0 | Batch_idx: 500 |  Loss: (2.2744) | Acc: (25.44%) (8157/32064)
# Epoch: 0 | Batch_idx: 510 |  Loss: (2.2631) | Acc: (25.66%) (8392/32704)
# Epoch: 0 | Batch_idx: 520 |  Loss: (2.2509) | Acc: (25.97%) (8658/33344)
# Epoch: 0 | Batch_idx: 530 |  Loss: (2.2403) | Acc: (26.17%) (8893/33984)
# Epoch: 0 | Batch_idx: 540 |  Loss: (2.2293) | Acc: (26.39%) (9137/34624)
# Epoch: 0 | Batch_idx: 550 |  Loss: (2.2183) | Acc: (26.58%) (9374/35264)
# Epoch: 0 | Batch_idx: 560 |  Loss: (2.2089) | Acc: (26.80%) (9622/35904)
# Epoch: 0 | Batch_idx: 570 |  Loss: (2.1991) | Acc: (26.97%) (9855/36544)
# Epoch: 0 | Batch_idx: 580 |  Loss: (2.1903) | Acc: (27.15%) (10096/37184)
# Epoch: 0 | Batch_idx: 590 |  Loss: (2.1817) | Acc: (27.28%) (10320/37824)
# Epoch: 0 | Batch_idx: 600 |  Loss: (2.1719) | Acc: (27.52%) (10585/38464)
# Epoch: 0 | Batch_idx: 610 |  Loss: (2.1627) | Acc: (27.75%) (10852/39104)
# Epoch: 0 | Batch_idx: 620 |  Loss: (2.1550) | Acc: (27.90%) (11090/39744)
# Epoch: 0 | Batch_idx: 630 |  Loss: (2.1472) | Acc: (28.04%) (11324/40384)
# Epoch: 0 | Batch_idx: 640 |  Loss: (2.1390) | Acc: (28.26%) (11594/41024)
# Epoch: 0 | Batch_idx: 650 |  Loss: (2.1311) | Acc: (28.43%) (11846/41664)
# Epoch: 0 | Batch_idx: 660 |  Loss: (2.1233) | Acc: (28.59%) (12096/42304)
# Epoch: 0 | Batch_idx: 670 |  Loss: (2.1162) | Acc: (28.74%) (12342/42944)
# Epoch: 0 | Batch_idx: 680 |  Loss: (2.1080) | Acc: (28.93%) (12607/43584)
# Epoch: 0 | Batch_idx: 690 |  Loss: (2.1004) | Acc: (29.08%) (12861/44224)
# Epoch: 0 | Batch_idx: 700 |  Loss: (2.0921) | Acc: (29.27%) (13132/44864)
# Epoch: 0 | Batch_idx: 710 |  Loss: (2.0844) | Acc: (29.45%) (13402/45504)
# Epoch: 0 | Batch_idx: 720 |  Loss: (2.0766) | Acc: (29.67%) (13692/46144)
# Epoch: 0 | Batch_idx: 730 |  Loss: (2.0691) | Acc: (29.88%) (13980/46784)
# Epoch: 0 | Batch_idx: 740 |  Loss: (2.0617) | Acc: (30.04%) (14248/47424)
# Epoch: 0 | Batch_idx: 750 |  Loss: (2.0551) | Acc: (30.18%) (14504/48064)
# Epoch: 0 | Batch_idx: 760 |  Loss: (2.0485) | Acc: (30.36%) (14787/48704)
# Epoch: 0 | Batch_idx: 770 |  Loss: (2.0415) | Acc: (30.54%) (15070/49344)
# Epoch: 0 | Batch_idx: 780 |  Loss: (2.0352) | Acc: (30.71%) (15352/49984)
# => saving checkpoint
# # TEST : Loss: (1.5851) | Acc: (43.39%) (4339/10000)
# Epoch: 1 | Batch_idx: 0 |  Loss: (1.6759) | Acc: (35.94%) (23/64)
# Epoch: 1 | Batch_idx: 10 |  Loss: (1.5534) | Acc: (43.47%) (306/704)
# Epoch: 1 | Batch_idx: 20 |  Loss: (1.5386) | Acc: (43.90%) (590/1344)
# Epoch: 1 | Batch_idx: 30 |  Loss: (1.5516) | Acc: (43.85%) (870/1984)
# Epoch: 1 | Batch_idx: 40 |  Loss: (1.5279) | Acc: (44.51%) (1168/2624)
# Epoch: 1 | Batch_idx: 50 |  Loss: (1.5402) | Acc: (44.00%) (1436/3264)
# Epoch: 1 | Batch_idx: 60 |  Loss: (1.5275) | Acc: (44.42%) (1734/3904)
# Epoch: 1 | Batch_idx: 70 |  Loss: (1.5210) | Acc: (44.17%) (2007/4544)
# Epoch: 1 | Batch_idx: 80 |  Loss: (1.5202) | Acc: (44.04%) (2283/5184)
# Epoch: 1 | Batch_idx: 90 |  Loss: (1.5186) | Acc: (43.92%) (2558/5824)
# Epoch: 1 | Batch_idx: 100 |  Loss: (1.5208) | Acc: (43.83%) (2833/6464)
# Epoch: 1 | Batch_idx: 110 |  Loss: (1.5152) | Acc: (43.74%) (3107/7104)
# Epoch: 1 | Batch_idx: 120 |  Loss: (1.5053) | Acc: (43.96%) (3404/7744)
# Epoch: 1 | Batch_idx: 130 |  Loss: (1.5091) | Acc: (43.88%) (3679/8384)
# Epoch: 1 | Batch_idx: 140 |  Loss: (1.5036) | Acc: (44.25%) (3993/9024)
# Epoch: 1 | Batch_idx: 150 |  Loss: (1.4988) | Acc: (44.48%) (4299/9664)
# Epoch: 1 | Batch_idx: 160 |  Loss: (1.5004) | Acc: (44.34%) (4569/10304)
# Epoch: 1 | Batch_idx: 170 |  Loss: (1.4940) | Acc: (44.63%) (4884/10944)
# Epoch: 1 | Batch_idx: 180 |  Loss: (1.4915) | Acc: (44.70%) (5178/11584)
# Epoch: 1 | Batch_idx: 190 |  Loss: (1.4893) | Acc: (44.81%) (5478/12224)
# Epoch: 1 | Batch_idx: 200 |  Loss: (1.4872) | Acc: (45.02%) (5792/12864)
# Epoch: 1 | Batch_idx: 210 |  Loss: (1.4862) | Acc: (45.13%) (6095/13504)
# Epoch: 1 | Batch_idx: 220 |  Loss: (1.4850) | Acc: (45.18%) (6390/14144)
# Epoch: 1 | Batch_idx: 230 |  Loss: (1.4807) | Acc: (45.34%) (6703/14784)
# Epoch: 1 | Batch_idx: 240 |  Loss: (1.4775) | Acc: (45.56%) (7027/15424)
# Epoch: 1 | Batch_idx: 250 |  Loss: (1.4745) | Acc: (45.69%) (7340/16064)
# Epoch: 1 | Batch_idx: 260 |  Loss: (1.4735) | Acc: (45.74%) (7641/16704)
# Epoch: 1 | Batch_idx: 270 |  Loss: (1.4726) | Acc: (45.81%) (7945/17344)
# Epoch: 1 | Batch_idx: 280 |  Loss: (1.4699) | Acc: (45.91%) (8257/17984)
# Epoch: 1 | Batch_idx: 290 |  Loss: (1.4683) | Acc: (46.04%) (8575/18624)
# Epoch: 1 | Batch_idx: 300 |  Loss: (1.4675) | Acc: (46.08%) (8877/19264)
# Epoch: 1 | Batch_idx: 310 |  Loss: (1.4659) | Acc: (46.10%) (9176/19904)
# Epoch: 1 | Batch_idx: 320 |  Loss: (1.4639) | Acc: (46.24%) (9499/20544)
# Epoch: 1 | Batch_idx: 330 |  Loss: (1.4600) | Acc: (46.34%) (9817/21184)
# Epoch: 1 | Batch_idx: 340 |  Loss: (1.4591) | Acc: (46.39%) (10125/21824)
# Epoch: 1 | Batch_idx: 350 |  Loss: (1.4590) | Acc: (46.43%) (10431/22464)
# Epoch: 1 | Batch_idx: 360 |  Loss: (1.4569) | Acc: (46.50%) (10743/23104)
# Epoch: 1 | Batch_idx: 370 |  Loss: (1.4529) | Acc: (46.59%) (11063/23744)
# Epoch: 1 | Batch_idx: 380 |  Loss: (1.4507) | Acc: (46.73%) (11394/24384)
# Epoch: 1 | Batch_idx: 390 |  Loss: (1.4490) | Acc: (46.84%) (11720/25024)
# Epoch: 1 | Batch_idx: 400 |  Loss: (1.4465) | Acc: (46.88%) (12030/25664)
# Epoch: 1 | Batch_idx: 410 |  Loss: (1.4451) | Acc: (46.86%) (12327/26304)
# Epoch: 1 | Batch_idx: 420 |  Loss: (1.4431) | Acc: (46.96%) (12653/26944)
# Epoch: 1 | Batch_idx: 430 |  Loss: (1.4385) | Acc: (47.13%) (13000/27584)
# Epoch: 1 | Batch_idx: 440 |  Loss: (1.4348) | Acc: (47.25%) (13337/28224)
# Epoch: 1 | Batch_idx: 450 |  Loss: (1.4338) | Acc: (47.33%) (13661/28864)
# Epoch: 1 | Batch_idx: 460 |  Loss: (1.4333) | Acc: (47.36%) (13974/29504)
# Epoch: 1 | Batch_idx: 470 |  Loss: (1.4316) | Acc: (47.44%) (14300/30144)
# Epoch: 1 | Batch_idx: 480 |  Loss: (1.4293) | Acc: (47.57%) (14644/30784)
# Epoch: 1 | Batch_idx: 490 |  Loss: (1.4272) | Acc: (47.66%) (14978/31424)
# Epoch: 1 | Batch_idx: 500 |  Loss: (1.4252) | Acc: (47.75%) (15311/32064)
# Epoch: 1 | Batch_idx: 510 |  Loss: (1.4248) | Acc: (47.83%) (15643/32704)
# Epoch: 1 | Batch_idx: 520 |  Loss: (1.4218) | Acc: (47.98%) (15998/33344)
# Epoch: 1 | Batch_idx: 530 |  Loss: (1.4201) | Acc: (48.08%) (16338/33984)
# Epoch: 1 | Batch_idx: 540 |  Loss: (1.4178) | Acc: (48.20%) (16688/34624)
# Epoch: 1 | Batch_idx: 550 |  Loss: (1.4152) | Acc: (48.30%) (17034/35264)
# Epoch: 1 | Batch_idx: 560 |  Loss: (1.4137) | Acc: (48.39%) (17375/35904)
# Epoch: 1 | Batch_idx: 570 |  Loss: (1.4100) | Acc: (48.52%) (17731/36544)
# Epoch: 1 | Batch_idx: 580 |  Loss: (1.4083) | Acc: (48.60%) (18070/37184)
# Epoch: 1 | Batch_idx: 590 |  Loss: (1.4061) | Acc: (48.69%) (18415/37824)
# Epoch: 1 | Batch_idx: 600 |  Loss: (1.4046) | Acc: (48.77%) (18758/38464)
# Epoch: 1 | Batch_idx: 610 |  Loss: (1.4037) | Acc: (48.79%) (19077/39104)
# Epoch: 1 | Batch_idx: 620 |  Loss: (1.4010) | Acc: (48.91%) (19439/39744)
# Epoch: 1 | Batch_idx: 630 |  Loss: (1.3987) | Acc: (48.99%) (19786/40384)
# Epoch: 1 | Batch_idx: 640 |  Loss: (1.3969) | Acc: (49.10%) (20142/41024)
# Epoch: 1 | Batch_idx: 650 |  Loss: (1.3948) | Acc: (49.17%) (20486/41664)
# Epoch: 1 | Batch_idx: 660 |  Loss: (1.3925) | Acc: (49.24%) (20831/42304)
# Epoch: 1 | Batch_idx: 670 |  Loss: (1.3899) | Acc: (49.34%) (21188/42944)
# Epoch: 1 | Batch_idx: 680 |  Loss: (1.3885) | Acc: (49.42%) (21540/43584)
# Epoch: 1 | Batch_idx: 690 |  Loss: (1.3862) | Acc: (49.53%) (21905/44224)
# Epoch: 1 | Batch_idx: 700 |  Loss: (1.3844) | Acc: (49.60%) (22252/44864)
# Epoch: 1 | Batch_idx: 710 |  Loss: (1.3826) | Acc: (49.66%) (22596/45504)
# Epoch: 1 | Batch_idx: 720 |  Loss: (1.3813) | Acc: (49.69%) (22930/46144)
# Epoch: 1 | Batch_idx: 730 |  Loss: (1.3790) | Acc: (49.76%) (23281/46784)
# Epoch: 1 | Batch_idx: 740 |  Loss: (1.3771) | Acc: (49.84%) (23637/47424)
# Epoch: 1 | Batch_idx: 750 |  Loss: (1.3753) | Acc: (49.92%) (23992/48064)
# Epoch: 1 | Batch_idx: 760 |  Loss: (1.3731) | Acc: (50.00%) (24351/48704)
# Epoch: 1 | Batch_idx: 770 |  Loss: (1.3719) | Acc: (50.03%) (24686/49344)
# Epoch: 1 | Batch_idx: 780 |  Loss: (1.3698) | Acc: (50.09%) (25035/49984)
# => saving checkpoint
# # TEST : Loss: (1.2108) | Acc: (56.24%) (5624/10000)
# Epoch: 2 | Batch_idx: 0 |  Loss: (1.2491) | Acc: (51.56%) (33/64)
# Epoch: 2 | Batch_idx: 10 |  Loss: (1.2583) | Acc: (54.40%) (383/704)
# Epoch: 2 | Batch_idx: 20 |  Loss: (1.2091) | Acc: (56.32%) (757/1344)
# Epoch: 2 | Batch_idx: 30 |  Loss: (1.1934) | Acc: (57.06%) (1132/1984)
# Epoch: 2 | Batch_idx: 40 |  Loss: (1.1822) | Acc: (57.05%) (1497/2624)
# Epoch: 2 | Batch_idx: 50 |  Loss: (1.1566) | Acc: (58.27%) (1902/3264)
# Epoch: 2 | Batch_idx: 60 |  Loss: (1.1623) | Acc: (57.81%) (2257/3904)
# Epoch: 2 | Batch_idx: 70 |  Loss: (1.1707) | Acc: (57.61%) (2618/4544)
# Epoch: 2 | Batch_idx: 80 |  Loss: (1.1580) | Acc: (58.29%) (3022/5184)
# Epoch: 2 | Batch_idx: 90 |  Loss: (1.1633) | Acc: (58.14%) (3386/5824)
# Epoch: 2 | Batch_idx: 100 |  Loss: (1.1611) | Acc: (58.29%) (3768/6464)
# Epoch: 2 | Batch_idx: 110 |  Loss: (1.1653) | Acc: (58.25%) (4138/7104)
# Epoch: 2 | Batch_idx: 120 |  Loss: (1.1680) | Acc: (58.14%) (4502/7744)
# Epoch: 2 | Batch_idx: 130 |  Loss: (1.1684) | Acc: (58.03%) (4865/8384)
# Epoch: 2 | Batch_idx: 140 |  Loss: (1.1695) | Acc: (58.01%) (5235/9024)
# Epoch: 2 | Batch_idx: 150 |  Loss: (1.1639) | Acc: (58.35%) (5639/9664)
# Epoch: 2 | Batch_idx: 160 |  Loss: (1.1650) | Acc: (58.25%) (6002/10304)
# Epoch: 2 | Batch_idx: 170 |  Loss: (1.1611) | Acc: (58.37%) (6388/10944)
# Epoch: 2 | Batch_idx: 180 |  Loss: (1.1641) | Acc: (58.17%) (6738/11584)
# Epoch: 2 | Batch_idx: 190 |  Loss: (1.1619) | Acc: (58.21%) (7115/12224)
# Epoch: 2 | Batch_idx: 200 |  Loss: (1.1646) | Acc: (58.13%) (7478/12864)
# Epoch: 2 | Batch_idx: 210 |  Loss: (1.1643) | Acc: (58.08%) (7843/13504)
# Epoch: 2 | Batch_idx: 220 |  Loss: (1.1617) | Acc: (58.24%) (8237/14144)
# Epoch: 2 | Batch_idx: 230 |  Loss: (1.1618) | Acc: (58.24%) (8610/14784)
# Epoch: 2 | Batch_idx: 240 |  Loss: (1.1614) | Acc: (58.38%) (9005/15424)
# Epoch: 2 | Batch_idx: 250 |  Loss: (1.1580) | Acc: (58.51%) (9399/16064)
# Epoch: 2 | Batch_idx: 260 |  Loss: (1.1580) | Acc: (58.42%) (9759/16704)
# Epoch: 2 | Batch_idx: 270 |  Loss: (1.1613) | Acc: (58.36%) (10122/17344)
# Epoch: 2 | Batch_idx: 280 |  Loss: (1.1636) | Acc: (58.33%) (10490/17984)
# Epoch: 2 | Batch_idx: 290 |  Loss: (1.1619) | Acc: (58.47%) (10889/18624)
# Epoch: 2 | Batch_idx: 300 |  Loss: (1.1597) | Acc: (58.58%) (11284/19264)
# Epoch: 2 | Batch_idx: 310 |  Loss: (1.1594) | Acc: (58.60%) (11663/19904)
# Epoch: 2 | Batch_idx: 320 |  Loss: (1.1573) | Acc: (58.66%) (12051/20544)
# Epoch: 2 | Batch_idx: 330 |  Loss: (1.1572) | Acc: (58.66%) (12426/21184)
# Epoch: 2 | Batch_idx: 340 |  Loss: (1.1555) | Acc: (58.69%) (12809/21824)
# Epoch: 2 | Batch_idx: 350 |  Loss: (1.1537) | Acc: (58.77%) (13203/22464)
# Epoch: 2 | Batch_idx: 360 |  Loss: (1.1531) | Acc: (58.80%) (13585/23104)
# Epoch: 2 | Batch_idx: 370 |  Loss: (1.1516) | Acc: (58.84%) (13971/23744)
# Epoch: 2 | Batch_idx: 380 |  Loss: (1.1498) | Acc: (58.92%) (14368/24384)
# Epoch: 2 | Batch_idx: 390 |  Loss: (1.1482) | Acc: (58.96%) (14755/25024)
# Epoch: 2 | Batch_idx: 400 |  Loss: (1.1490) | Acc: (58.95%) (15128/25664)
# Epoch: 2 | Batch_idx: 410 |  Loss: (1.1478) | Acc: (58.96%) (15508/26304)
# Epoch: 2 | Batch_idx: 420 |  Loss: (1.1471) | Acc: (59.04%) (15907/26944)
# Epoch: 2 | Batch_idx: 430 |  Loss: (1.1460) | Acc: (59.10%) (16303/27584)
# Epoch: 2 | Batch_idx: 440 |  Loss: (1.1450) | Acc: (59.10%) (16679/28224)
# Epoch: 2 | Batch_idx: 450 |  Loss: (1.1433) | Acc: (59.15%) (17073/28864)
# Epoch: 2 | Batch_idx: 460 |  Loss: (1.1419) | Acc: (59.21%) (17469/29504)
# Epoch: 2 | Batch_idx: 470 |  Loss: (1.1418) | Acc: (59.26%) (17863/30144)
# Epoch: 2 | Batch_idx: 480 |  Loss: (1.1395) | Acc: (59.33%) (18265/30784)
# Epoch: 2 | Batch_idx: 490 |  Loss: (1.1386) | Acc: (59.39%) (18663/31424)
# Epoch: 2 | Batch_idx: 500 |  Loss: (1.1362) | Acc: (59.47%) (19070/32064)
# Epoch: 2 | Batch_idx: 510 |  Loss: (1.1349) | Acc: (59.56%) (19478/32704)
# Epoch: 2 | Batch_idx: 520 |  Loss: (1.1341) | Acc: (59.60%) (19872/33344)
# Epoch: 2 | Batch_idx: 530 |  Loss: (1.1327) | Acc: (59.64%) (20267/33984)
# Epoch: 2 | Batch_idx: 540 |  Loss: (1.1299) | Acc: (59.77%) (20696/34624)
# Epoch: 2 | Batch_idx: 550 |  Loss: (1.1277) | Acc: (59.79%) (21085/35264)
# Epoch: 2 | Batch_idx: 560 |  Loss: (1.1271) | Acc: (59.83%) (21482/35904)
# Epoch: 2 | Batch_idx: 570 |  Loss: (1.1261) | Acc: (59.87%) (21878/36544)
# Epoch: 2 | Batch_idx: 580 |  Loss: (1.1249) | Acc: (59.89%) (22269/37184)
# Epoch: 2 | Batch_idx: 590 |  Loss: (1.1230) | Acc: (59.96%) (22678/37824)
# Epoch: 2 | Batch_idx: 600 |  Loss: (1.1220) | Acc: (60.00%) (23078/38464)
# Epoch: 2 | Batch_idx: 610 |  Loss: (1.1215) | Acc: (59.99%) (23459/39104)
# Epoch: 2 | Batch_idx: 620 |  Loss: (1.1209) | Acc: (60.02%) (23856/39744)
# Epoch: 2 | Batch_idx: 630 |  Loss: (1.1203) | Acc: (60.05%) (24250/40384)
# Epoch: 2 | Batch_idx: 640 |  Loss: (1.1192) | Acc: (60.09%) (24652/41024)
# Epoch: 2 | Batch_idx: 650 |  Loss: (1.1181) | Acc: (60.13%) (25054/41664)
# Epoch: 2 | Batch_idx: 660 |  Loss: (1.1168) | Acc: (60.20%) (25465/42304)
# Epoch: 2 | Batch_idx: 670 |  Loss: (1.1156) | Acc: (60.22%) (25860/42944)
# Epoch: 2 | Batch_idx: 680 |  Loss: (1.1136) | Acc: (60.29%) (26276/43584)
# Epoch: 2 | Batch_idx: 690 |  Loss: (1.1119) | Acc: (60.37%) (26698/44224)
# Epoch: 2 | Batch_idx: 700 |  Loss: (1.1101) | Acc: (60.46%) (27123/44864)
# Epoch: 2 | Batch_idx: 710 |  Loss: (1.1086) | Acc: (60.49%) (27526/45504)
# Epoch: 2 | Batch_idx: 720 |  Loss: (1.1065) | Acc: (60.57%) (27951/46144)
# Epoch: 2 | Batch_idx: 730 |  Loss: (1.1052) | Acc: (60.65%) (28375/46784)
# Epoch: 2 | Batch_idx: 740 |  Loss: (1.1060) | Acc: (60.61%) (28744/47424)
# Epoch: 2 | Batch_idx: 750 |  Loss: (1.1057) | Acc: (60.65%) (29152/48064)
# Epoch: 2 | Batch_idx: 760 |  Loss: (1.1047) | Acc: (60.70%) (29564/48704)
# Epoch: 2 | Batch_idx: 770 |  Loss: (1.1034) | Acc: (60.76%) (29982/49344)
# Epoch: 2 | Batch_idx: 780 |  Loss: (1.1035) | Acc: (60.77%) (30375/49984)
# => saving checkpoint
# # TEST : Loss: (0.9927) | Acc: (64.65%) (6465/10000)
# Epoch: 3 | Batch_idx: 0 |  Loss: (1.0403) | Acc: (60.94%) (39/64)
# Epoch: 3 | Batch_idx: 10 |  Loss: (1.0211) | Acc: (64.91%) (457/704)
# Epoch: 3 | Batch_idx: 20 |  Loss: (0.9926) | Acc: (65.77%) (884/1344)
# Epoch: 3 | Batch_idx: 30 |  Loss: (0.9966) | Acc: (64.97%) (1289/1984)
# Epoch: 3 | Batch_idx: 40 |  Loss: (1.0019) | Acc: (64.75%) (1699/2624)
# Epoch: 3 | Batch_idx: 50 |  Loss: (1.0103) | Acc: (64.37%) (2101/3264)
# Epoch: 3 | Batch_idx: 60 |  Loss: (1.0097) | Acc: (64.22%) (2507/3904)
# Epoch: 3 | Batch_idx: 70 |  Loss: (0.9936) | Acc: (64.74%) (2942/4544)
# Epoch: 3 | Batch_idx: 80 |  Loss: (0.9834) | Acc: (65.10%) (3375/5184)
# Epoch: 3 | Batch_idx: 90 |  Loss: (0.9850) | Acc: (65.18%) (3796/5824)
# Epoch: 3 | Batch_idx: 100 |  Loss: (0.9811) | Acc: (65.32%) (4222/6464)
# Epoch: 3 | Batch_idx: 110 |  Loss: (0.9754) | Acc: (65.57%) (4658/7104)
# Epoch: 3 | Batch_idx: 120 |  Loss: (0.9685) | Acc: (65.81%) (5096/7744)
# Epoch: 3 | Batch_idx: 130 |  Loss: (0.9700) | Acc: (65.55%) (5496/8384)
# Epoch: 3 | Batch_idx: 140 |  Loss: (0.9668) | Acc: (65.78%) (5936/9024)
# Epoch: 3 | Batch_idx: 150 |  Loss: (0.9646) | Acc: (65.89%) (6368/9664)
# Epoch: 3 | Batch_idx: 160 |  Loss: (0.9630) | Acc: (65.97%) (6798/10304)
# Epoch: 3 | Batch_idx: 170 |  Loss: (0.9646) | Acc: (65.95%) (7218/10944)
# Epoch: 3 | Batch_idx: 180 |  Loss: (0.9639) | Acc: (65.94%) (7638/11584)
# Epoch: 3 | Batch_idx: 190 |  Loss: (0.9646) | Acc: (65.83%) (8047/12224)
# Epoch: 3 | Batch_idx: 200 |  Loss: (0.9627) | Acc: (65.84%) (8470/12864)
# Epoch: 3 | Batch_idx: 210 |  Loss: (0.9660) | Acc: (65.72%) (8875/13504)
# Epoch: 3 | Batch_idx: 220 |  Loss: (0.9673) | Acc: (65.62%) (9281/14144)
# Epoch: 3 | Batch_idx: 230 |  Loss: (0.9650) | Acc: (65.73%) (9718/14784)
# Epoch: 3 | Batch_idx: 240 |  Loss: (0.9671) | Acc: (65.62%) (10121/15424)
# Epoch: 3 | Batch_idx: 250 |  Loss: (0.9654) | Acc: (65.69%) (10553/16064)
# Epoch: 3 | Batch_idx: 260 |  Loss: (0.9621) | Acc: (65.84%) (10998/16704)
# Epoch: 3 | Batch_idx: 270 |  Loss: (0.9625) | Acc: (65.86%) (11422/17344)
# Epoch: 3 | Batch_idx: 280 |  Loss: (0.9638) | Acc: (65.80%) (11833/17984)
# Epoch: 3 | Batch_idx: 290 |  Loss: (0.9642) | Acc: (65.80%) (12254/18624)
# Epoch: 3 | Batch_idx: 300 |  Loss: (0.9637) | Acc: (65.88%) (12692/19264)
# Epoch: 3 | Batch_idx: 310 |  Loss: (0.9607) | Acc: (65.93%) (13122/19904)
# Epoch: 3 | Batch_idx: 320 |  Loss: (0.9578) | Acc: (66.00%) (13560/20544)
# Epoch: 3 | Batch_idx: 330 |  Loss: (0.9558) | Acc: (66.10%) (14003/21184)
# Epoch: 3 | Batch_idx: 340 |  Loss: (0.9552) | Acc: (66.06%) (14418/21824)
# Epoch: 3 | Batch_idx: 350 |  Loss: (0.9554) | Acc: (66.13%) (14855/22464)
# Epoch: 3 | Batch_idx: 360 |  Loss: (0.9559) | Acc: (66.17%) (15289/23104)
# Epoch: 3 | Batch_idx: 370 |  Loss: (0.9548) | Acc: (66.19%) (15715/23744)
# Epoch: 3 | Batch_idx: 380 |  Loss: (0.9545) | Acc: (66.20%) (16142/24384)
# Epoch: 3 | Batch_idx: 390 |  Loss: (0.9528) | Acc: (66.28%) (16587/25024)
# Epoch: 3 | Batch_idx: 400 |  Loss: (0.9513) | Acc: (66.34%) (17026/25664)
# Epoch: 3 | Batch_idx: 410 |  Loss: (0.9516) | Acc: (66.33%) (17448/26304)
# Epoch: 3 | Batch_idx: 420 |  Loss: (0.9505) | Acc: (66.40%) (17892/26944)
# Epoch: 3 | Batch_idx: 430 |  Loss: (0.9483) | Acc: (66.48%) (18338/27584)
# Epoch: 3 | Batch_idx: 440 |  Loss: (0.9482) | Acc: (66.48%) (18764/28224)
# Epoch: 3 | Batch_idx: 450 |  Loss: (0.9473) | Acc: (66.56%) (19211/28864)
# Epoch: 3 | Batch_idx: 460 |  Loss: (0.9464) | Acc: (66.60%) (19650/29504)
# Epoch: 3 | Batch_idx: 470 |  Loss: (0.9461) | Acc: (66.61%) (20080/30144)
# Epoch: 3 | Batch_idx: 480 |  Loss: (0.9457) | Acc: (66.63%) (20512/30784)
# Epoch: 3 | Batch_idx: 490 |  Loss: (0.9465) | Acc: (66.56%) (20917/31424)
# Epoch: 3 | Batch_idx: 500 |  Loss: (0.9462) | Acc: (66.55%) (21340/32064)
# Epoch: 3 | Batch_idx: 510 |  Loss: (0.9467) | Acc: (66.57%) (21770/32704)
# Epoch: 3 | Batch_idx: 520 |  Loss: (0.9477) | Acc: (66.52%) (22179/33344)
# Epoch: 3 | Batch_idx: 530 |  Loss: (0.9466) | Acc: (66.55%) (22615/33984)
# Epoch: 3 | Batch_idx: 540 |  Loss: (0.9460) | Acc: (66.58%) (23051/34624)
# Epoch: 3 | Batch_idx: 550 |  Loss: (0.9466) | Acc: (66.56%) (23471/35264)
# Epoch: 3 | Batch_idx: 560 |  Loss: (0.9451) | Acc: (66.60%) (23912/35904)
# Epoch: 3 | Batch_idx: 570 |  Loss: (0.9442) | Acc: (66.68%) (24366/36544)
# Epoch: 3 | Batch_idx: 580 |  Loss: (0.9432) | Acc: (66.66%) (24785/37184)
# Epoch: 3 | Batch_idx: 590 |  Loss: (0.9426) | Acc: (66.66%) (25214/37824)
# Epoch: 3 | Batch_idx: 600 |  Loss: (0.9428) | Acc: (66.67%) (25643/38464)
# Epoch: 3 | Batch_idx: 610 |  Loss: (0.9435) | Acc: (66.64%) (26057/39104)
# Epoch: 3 | Batch_idx: 620 |  Loss: (0.9424) | Acc: (66.65%) (26490/39744)
# Epoch: 3 | Batch_idx: 630 |  Loss: (0.9421) | Acc: (66.68%) (26930/40384)
# Epoch: 3 | Batch_idx: 640 |  Loss: (0.9415) | Acc: (66.73%) (27374/41024)
# Epoch: 3 | Batch_idx: 650 |  Loss: (0.9413) | Acc: (66.74%) (27805/41664)
# Epoch: 3 | Batch_idx: 660 |  Loss: (0.9401) | Acc: (66.78%) (28251/42304)
# Epoch: 3 | Batch_idx: 670 |  Loss: (0.9387) | Acc: (66.83%) (28700/42944)
# Epoch: 3 | Batch_idx: 680 |  Loss: (0.9372) | Acc: (66.89%) (29152/43584)
# Epoch: 3 | Batch_idx: 690 |  Loss: (0.9363) | Acc: (66.90%) (29585/44224)
# Epoch: 3 | Batch_idx: 700 |  Loss: (0.9364) | Acc: (66.89%) (30010/44864)
# Epoch: 3 | Batch_idx: 710 |  Loss: (0.9359) | Acc: (66.93%) (30455/45504)
# Epoch: 3 | Batch_idx: 720 |  Loss: (0.9344) | Acc: (66.99%) (30911/46144)
# Epoch: 3 | Batch_idx: 730 |  Loss: (0.9344) | Acc: (67.00%) (31347/46784)
# Epoch: 3 | Batch_idx: 740 |  Loss: (0.9341) | Acc: (67.02%) (31785/47424)
# Epoch: 3 | Batch_idx: 750 |  Loss: (0.9336) | Acc: (67.05%) (32227/48064)
# Epoch: 3 | Batch_idx: 760 |  Loss: (0.9332) | Acc: (67.03%) (32645/48704)
# Epoch: 3 | Batch_idx: 770 |  Loss: (0.9330) | Acc: (67.04%) (33081/49344)
# Epoch: 3 | Batch_idx: 780 |  Loss: (0.9319) | Acc: (67.07%) (33524/49984)
# => saving checkpoint
# # TEST : Loss: (1.0454) | Acc: (64.11%) (6411/10000)
# Epoch: 4 | Batch_idx: 0 |  Loss: (0.7077) | Acc: (75.00%) (48/64)
# Epoch: 4 | Batch_idx: 10 |  Loss: (0.8700) | Acc: (68.89%) (485/704)
# Epoch: 4 | Batch_idx: 20 |  Loss: (0.8445) | Acc: (69.27%) (931/1344)
# Epoch: 4 | Batch_idx: 30 |  Loss: (0.8450) | Acc: (69.56%) (1380/1984)
# Epoch: 4 | Batch_idx: 40 |  Loss: (0.8535) | Acc: (69.66%) (1828/2624)
# Epoch: 4 | Batch_idx: 50 |  Loss: (0.8443) | Acc: (70.25%) (2293/3264)
# Epoch: 4 | Batch_idx: 60 |  Loss: (0.8425) | Acc: (70.47%) (2751/3904)
# Epoch: 4 | Batch_idx: 70 |  Loss: (0.8434) | Acc: (70.47%) (3202/4544)
# Epoch: 4 | Batch_idx: 80 |  Loss: (0.8467) | Acc: (70.58%) (3659/5184)
# Epoch: 4 | Batch_idx: 90 |  Loss: (0.8409) | Acc: (70.40%) (4100/5824)
# Epoch: 4 | Batch_idx: 100 |  Loss: (0.8414) | Acc: (70.45%) (4554/6464)
# Epoch: 4 | Batch_idx: 110 |  Loss: (0.8439) | Acc: (70.44%) (5004/7104)
# Epoch: 4 | Batch_idx: 120 |  Loss: (0.8405) | Acc: (70.60%) (5467/7744)
# Epoch: 4 | Batch_idx: 130 |  Loss: (0.8360) | Acc: (70.71%) (5928/8384)
# Epoch: 4 | Batch_idx: 140 |  Loss: (0.8379) | Acc: (70.48%) (6360/9024)
# Epoch: 4 | Batch_idx: 150 |  Loss: (0.8371) | Acc: (70.58%) (6821/9664)
# Epoch: 4 | Batch_idx: 160 |  Loss: (0.8340) | Acc: (70.63%) (7278/10304)
# Epoch: 4 | Batch_idx: 170 |  Loss: (0.8367) | Acc: (70.41%) (7706/10944)
# Epoch: 4 | Batch_idx: 180 |  Loss: (0.8364) | Acc: (70.37%) (8152/11584)
# Epoch: 4 | Batch_idx: 190 |  Loss: (0.8336) | Acc: (70.52%) (8620/12224)
# Epoch: 4 | Batch_idx: 200 |  Loss: (0.8324) | Acc: (70.53%) (9073/12864)
# Epoch: 4 | Batch_idx: 210 |  Loss: (0.8326) | Acc: (70.62%) (9537/13504)
# Epoch: 4 | Batch_idx: 220 |  Loss: (0.8311) | Acc: (70.62%) (9989/14144)
# Epoch: 4 | Batch_idx: 230 |  Loss: (0.8300) | Acc: (70.64%) (10444/14784)
# Epoch: 4 | Batch_idx: 240 |  Loss: (0.8269) | Acc: (70.77%) (10915/15424)
# Epoch: 4 | Batch_idx: 250 |  Loss: (0.8262) | Acc: (70.80%) (11373/16064)
# Epoch: 4 | Batch_idx: 260 |  Loss: (0.8255) | Acc: (70.91%) (11845/16704)
# Epoch: 4 | Batch_idx: 270 |  Loss: (0.8262) | Acc: (70.84%) (12286/17344)
# Epoch: 4 | Batch_idx: 280 |  Loss: (0.8277) | Acc: (70.74%) (12722/17984)
# Epoch: 4 | Batch_idx: 290 |  Loss: (0.8281) | Acc: (70.70%) (13167/18624)
# Epoch: 4 | Batch_idx: 300 |  Loss: (0.8285) | Acc: (70.74%) (13628/19264)
# Epoch: 4 | Batch_idx: 310 |  Loss: (0.8273) | Acc: (70.75%) (14083/19904)
# Epoch: 4 | Batch_idx: 320 |  Loss: (0.8273) | Acc: (70.78%) (14542/20544)
# Epoch: 4 | Batch_idx: 330 |  Loss: (0.8264) | Acc: (70.86%) (15011/21184)
# Epoch: 4 | Batch_idx: 340 |  Loss: (0.8239) | Acc: (70.90%) (15473/21824)
# Epoch: 4 | Batch_idx: 350 |  Loss: (0.8236) | Acc: (70.93%) (15934/22464)
# Epoch: 4 | Batch_idx: 360 |  Loss: (0.8233) | Acc: (71.00%) (16404/23104)
# Epoch: 4 | Batch_idx: 370 |  Loss: (0.8214) | Acc: (71.04%) (16868/23744)
# Epoch: 4 | Batch_idx: 380 |  Loss: (0.8226) | Acc: (71.05%) (17324/24384)
# Epoch: 4 | Batch_idx: 390 |  Loss: (0.8216) | Acc: (71.10%) (17793/25024)
# Epoch: 4 | Batch_idx: 400 |  Loss: (0.8219) | Acc: (71.10%) (18248/25664)
# Epoch: 4 | Batch_idx: 410 |  Loss: (0.8221) | Acc: (71.08%) (18698/26304)
# Epoch: 4 | Batch_idx: 420 |  Loss: (0.8224) | Acc: (71.07%) (19150/26944)
# Epoch: 4 | Batch_idx: 430 |  Loss: (0.8225) | Acc: (71.12%) (19619/27584)
# Epoch: 4 | Batch_idx: 440 |  Loss: (0.8228) | Acc: (71.06%) (20055/28224)
# Epoch: 4 | Batch_idx: 450 |  Loss: (0.8210) | Acc: (71.16%) (20539/28864)
# Epoch: 4 | Batch_idx: 460 |  Loss: (0.8204) | Acc: (71.16%) (20995/29504)
# Epoch: 4 | Batch_idx: 470 |  Loss: (0.8207) | Acc: (71.16%) (21451/30144)
# Epoch: 4 | Batch_idx: 480 |  Loss: (0.8199) | Acc: (71.16%) (21905/30784)
# Epoch: 4 | Batch_idx: 490 |  Loss: (0.8190) | Acc: (71.17%) (22365/31424)
# Epoch: 4 | Batch_idx: 500 |  Loss: (0.8196) | Acc: (71.14%) (22811/32064)
# Epoch: 4 | Batch_idx: 510 |  Loss: (0.8193) | Acc: (71.14%) (23266/32704)
# Epoch: 4 | Batch_idx: 520 |  Loss: (0.8184) | Acc: (71.17%) (23731/33344)
# Epoch: 4 | Batch_idx: 530 |  Loss: (0.8173) | Acc: (71.19%) (24194/33984)
# Epoch: 4 | Batch_idx: 540 |  Loss: (0.8163) | Acc: (71.23%) (24662/34624)
# Epoch: 4 | Batch_idx: 550 |  Loss: (0.8163) | Acc: (71.21%) (25112/35264)
# Epoch: 4 | Batch_idx: 560 |  Loss: (0.8160) | Acc: (71.25%) (25580/35904)
# Epoch: 4 | Batch_idx: 570 |  Loss: (0.8154) | Acc: (71.29%) (26052/36544)
# Epoch: 4 | Batch_idx: 580 |  Loss: (0.8156) | Acc: (71.29%) (26510/37184)
# Epoch: 4 | Batch_idx: 590 |  Loss: (0.8161) | Acc: (71.27%) (26959/37824)
# Epoch: 4 | Batch_idx: 600 |  Loss: (0.8154) | Acc: (71.27%) (27413/38464)
# Epoch: 4 | Batch_idx: 610 |  Loss: (0.8131) | Acc: (71.33%) (27894/39104)
# Epoch: 4 | Batch_idx: 620 |  Loss: (0.8121) | Acc: (71.38%) (28368/39744)
# Epoch: 4 | Batch_idx: 630 |  Loss: (0.8104) | Acc: (71.43%) (28845/40384)
# Epoch: 4 | Batch_idx: 640 |  Loss: (0.8099) | Acc: (71.46%) (29315/41024)
# Epoch: 4 | Batch_idx: 650 |  Loss: (0.8095) | Acc: (71.44%) (29766/41664)
# Epoch: 4 | Batch_idx: 660 |  Loss: (0.8089) | Acc: (71.47%) (30236/42304)
# Epoch: 4 | Batch_idx: 670 |  Loss: (0.8089) | Acc: (71.49%) (30702/42944)
# Epoch: 4 | Batch_idx: 680 |  Loss: (0.8086) | Acc: (71.52%) (31171/43584)
# Epoch: 4 | Batch_idx: 690 |  Loss: (0.8084) | Acc: (71.53%) (31635/44224)
# Epoch: 4 | Batch_idx: 700 |  Loss: (0.8079) | Acc: (71.56%) (32104/44864)
# Epoch: 4 | Batch_idx: 710 |  Loss: (0.8081) | Acc: (71.56%) (32561/45504)
# Epoch: 4 | Batch_idx: 720 |  Loss: (0.8089) | Acc: (71.55%) (33015/46144)
# Epoch: 4 | Batch_idx: 730 |  Loss: (0.8086) | Acc: (71.55%) (33475/46784)
# Epoch: 4 | Batch_idx: 740 |  Loss: (0.8075) | Acc: (71.58%) (33944/47424)
# Epoch: 4 | Batch_idx: 750 |  Loss: (0.8075) | Acc: (71.60%) (34412/48064)
# Epoch: 4 | Batch_idx: 760 |  Loss: (0.8067) | Acc: (71.63%) (34886/48704)
# Epoch: 4 | Batch_idx: 770 |  Loss: (0.8064) | Acc: (71.66%) (35361/49344)
# Epoch: 4 | Batch_idx: 780 |  Loss: (0.8061) | Acc: (71.68%) (35830/49984)
# => saving checkpoint
# # TEST : Loss: (0.8012) | Acc: (72.15%) (7215/10000)
# Epoch: 5 | Batch_idx: 0 |  Loss: (0.8688) | Acc: (73.44%) (47/64)
# Epoch: 5 | Batch_idx: 10 |  Loss: (0.7088) | Acc: (74.29%) (523/704)
# Epoch: 5 | Batch_idx: 20 |  Loss: (0.7109) | Acc: (75.45%) (1014/1344)
# Epoch: 5 | Batch_idx: 30 |  Loss: (0.7072) | Acc: (76.06%) (1509/1984)
# Epoch: 5 | Batch_idx: 40 |  Loss: (0.6951) | Acc: (76.52%) (2008/2624)
# Epoch: 5 | Batch_idx: 50 |  Loss: (0.6916) | Acc: (76.38%) (2493/3264)
# Epoch: 5 | Batch_idx: 60 |  Loss: (0.6956) | Acc: (76.23%) (2976/3904)
# Epoch: 5 | Batch_idx: 70 |  Loss: (0.6981) | Acc: (75.77%) (3443/4544)
# Epoch: 5 | Batch_idx: 80 |  Loss: (0.7027) | Acc: (75.35%) (3906/5184)
# Epoch: 5 | Batch_idx: 90 |  Loss: (0.7077) | Acc: (75.15%) (4377/5824)
# Epoch: 5 | Batch_idx: 100 |  Loss: (0.7059) | Acc: (74.94%) (4844/6464)
# Epoch: 5 | Batch_idx: 110 |  Loss: (0.7079) | Acc: (74.89%) (5320/7104)
# Epoch: 5 | Batch_idx: 120 |  Loss: (0.7064) | Acc: (75.04%) (5811/7744)
# Epoch: 5 | Batch_idx: 130 |  Loss: (0.7083) | Acc: (74.93%) (6282/8384)
# Epoch: 5 | Batch_idx: 140 |  Loss: (0.7086) | Acc: (74.88%) (6757/9024)
# Epoch: 5 | Batch_idx: 150 |  Loss: (0.7097) | Acc: (74.81%) (7230/9664)
# Epoch: 5 | Batch_idx: 160 |  Loss: (0.7089) | Acc: (74.85%) (7713/10304)
# Epoch: 5 | Batch_idx: 170 |  Loss: (0.7126) | Acc: (74.85%) (8192/10944)
# Epoch: 5 | Batch_idx: 180 |  Loss: (0.7181) | Acc: (74.57%) (8638/11584)
# Epoch: 5 | Batch_idx: 190 |  Loss: (0.7149) | Acc: (74.69%) (9130/12224)
# Epoch: 5 | Batch_idx: 200 |  Loss: (0.7146) | Acc: (74.74%) (9615/12864)
# Epoch: 5 | Batch_idx: 210 |  Loss: (0.7186) | Acc: (74.60%) (10074/13504)
# Epoch: 5 | Batch_idx: 220 |  Loss: (0.7178) | Acc: (74.59%) (10550/14144)
# Epoch: 5 | Batch_idx: 230 |  Loss: (0.7171) | Acc: (74.67%) (11039/14784)
# Epoch: 5 | Batch_idx: 240 |  Loss: (0.7169) | Acc: (74.68%) (11519/15424)
# Epoch: 5 | Batch_idx: 250 |  Loss: (0.7172) | Acc: (74.68%) (11996/16064)
# Epoch: 5 | Batch_idx: 260 |  Loss: (0.7193) | Acc: (74.68%) (12475/16704)
# Epoch: 5 | Batch_idx: 270 |  Loss: (0.7190) | Acc: (74.65%) (12947/17344)
# Epoch: 5 | Batch_idx: 280 |  Loss: (0.7221) | Acc: (74.54%) (13405/17984)
# Epoch: 5 | Batch_idx: 290 |  Loss: (0.7224) | Acc: (74.54%) (13883/18624)
# Epoch: 5 | Batch_idx: 300 |  Loss: (0.7232) | Acc: (74.50%) (14351/19264)
# Epoch: 5 | Batch_idx: 310 |  Loss: (0.7223) | Acc: (74.55%) (14838/19904)
# Epoch: 5 | Batch_idx: 320 |  Loss: (0.7213) | Acc: (74.56%) (15317/20544)
# Epoch: 5 | Batch_idx: 330 |  Loss: (0.7198) | Acc: (74.59%) (15801/21184)
# Epoch: 5 | Batch_idx: 340 |  Loss: (0.7206) | Acc: (74.60%) (16280/21824)
# Epoch: 5 | Batch_idx: 350 |  Loss: (0.7186) | Acc: (74.71%) (16782/22464)
# Epoch: 5 | Batch_idx: 360 |  Loss: (0.7171) | Acc: (74.77%) (17274/23104)
# Epoch: 5 | Batch_idx: 370 |  Loss: (0.7170) | Acc: (74.75%) (17748/23744)
# Epoch: 5 | Batch_idx: 380 |  Loss: (0.7170) | Acc: (74.73%) (18223/24384)
# Epoch: 5 | Batch_idx: 390 |  Loss: (0.7199) | Acc: (74.65%) (18680/25024)
# Epoch: 5 | Batch_idx: 400 |  Loss: (0.7209) | Acc: (74.58%) (19141/25664)
# Epoch: 5 | Batch_idx: 410 |  Loss: (0.7193) | Acc: (74.63%) (19631/26304)
# Epoch: 5 | Batch_idx: 420 |  Loss: (0.7186) | Acc: (74.67%) (20118/26944)
# Epoch: 5 | Batch_idx: 430 |  Loss: (0.7187) | Acc: (74.65%) (20592/27584)
# Epoch: 5 | Batch_idx: 440 |  Loss: (0.7176) | Acc: (74.70%) (21084/28224)
# Epoch: 5 | Batch_idx: 450 |  Loss: (0.7177) | Acc: (74.71%) (21565/28864)
# Epoch: 5 | Batch_idx: 460 |  Loss: (0.7169) | Acc: (74.69%) (22038/29504)
# Epoch: 5 | Batch_idx: 470 |  Loss: (0.7175) | Acc: (74.68%) (22512/30144)
# Epoch: 5 | Batch_idx: 480 |  Loss: (0.7176) | Acc: (74.63%) (22974/30784)
# Epoch: 5 | Batch_idx: 490 |  Loss: (0.7169) | Acc: (74.63%) (23451/31424)
# Epoch: 5 | Batch_idx: 500 |  Loss: (0.7170) | Acc: (74.66%) (23939/32064)
# Epoch: 5 | Batch_idx: 510 |  Loss: (0.7158) | Acc: (74.71%) (24432/32704)
# Epoch: 5 | Batch_idx: 520 |  Loss: (0.7154) | Acc: (74.74%) (24921/33344)
# Epoch: 5 | Batch_idx: 530 |  Loss: (0.7134) | Acc: (74.79%) (25417/33984)
# Epoch: 5 | Batch_idx: 540 |  Loss: (0.7127) | Acc: (74.82%) (25906/34624)
# Epoch: 5 | Batch_idx: 550 |  Loss: (0.7130) | Acc: (74.83%) (26389/35264)
# Epoch: 5 | Batch_idx: 560 |  Loss: (0.7129) | Acc: (74.85%) (26874/35904)
# Epoch: 5 | Batch_idx: 570 |  Loss: (0.7127) | Acc: (74.89%) (27366/36544)
# Epoch: 5 | Batch_idx: 580 |  Loss: (0.7123) | Acc: (74.93%) (27861/37184)
# Epoch: 5 | Batch_idx: 590 |  Loss: (0.7112) | Acc: (74.94%) (28344/37824)
# Epoch: 5 | Batch_idx: 600 |  Loss: (0.7102) | Acc: (74.99%) (28846/38464)
# Epoch: 5 | Batch_idx: 610 |  Loss: (0.7101) | Acc: (74.97%) (29315/39104)
# Epoch: 5 | Batch_idx: 620 |  Loss: (0.7101) | Acc: (74.97%) (29798/39744)
# Epoch: 5 | Batch_idx: 630 |  Loss: (0.7097) | Acc: (74.98%) (30280/40384)
# Epoch: 5 | Batch_idx: 640 |  Loss: (0.7094) | Acc: (74.96%) (30753/41024)
# Epoch: 5 | Batch_idx: 650 |  Loss: (0.7090) | Acc: (74.98%) (31239/41664)
# Epoch: 5 | Batch_idx: 660 |  Loss: (0.7077) | Acc: (75.03%) (31741/42304)
# Epoch: 5 | Batch_idx: 670 |  Loss: (0.7075) | Acc: (75.02%) (32218/42944)
# Epoch: 5 | Batch_idx: 680 |  Loss: (0.7072) | Acc: (75.05%) (32710/43584)
# Epoch: 5 | Batch_idx: 690 |  Loss: (0.7068) | Acc: (75.07%) (33201/44224)
# Epoch: 5 | Batch_idx: 700 |  Loss: (0.7061) | Acc: (75.09%) (33689/44864)
# Epoch: 5 | Batch_idx: 710 |  Loss: (0.7054) | Acc: (75.12%) (34183/45504)
# Epoch: 5 | Batch_idx: 720 |  Loss: (0.7053) | Acc: (75.13%) (34666/46144)
# Epoch: 5 | Batch_idx: 730 |  Loss: (0.7058) | Acc: (75.11%) (35140/46784)
# Epoch: 5 | Batch_idx: 740 |  Loss: (0.7056) | Acc: (75.12%) (35624/47424)
# Epoch: 5 | Batch_idx: 750 |  Loss: (0.7052) | Acc: (75.14%) (36114/48064)
# Epoch: 5 | Batch_idx: 760 |  Loss: (0.7048) | Acc: (75.15%) (36600/48704)
# Epoch: 5 | Batch_idx: 770 |  Loss: (0.7046) | Acc: (75.16%) (37085/49344)
# Epoch: 5 | Batch_idx: 780 |  Loss: (0.7036) | Acc: (75.19%) (37585/49984)
# => saving checkpoint
# # TEST : Loss: (0.7088) | Acc: (76.17%) (7617/10000)
# Epoch: 6 | Batch_idx: 0 |  Loss: (0.6218) | Acc: (79.69%) (51/64)
# Epoch: 6 | Batch_idx: 10 |  Loss: (0.6380) | Acc: (78.55%) (553/704)
# Epoch: 6 | Batch_idx: 20 |  Loss: (0.6275) | Acc: (78.87%) (1060/1344)
# Epoch: 6 | Batch_idx: 30 |  Loss: (0.6404) | Acc: (78.18%) (1551/1984)
# Epoch: 6 | Batch_idx: 40 |  Loss: (0.6525) | Acc: (77.63%) (2037/2624)
# Epoch: 6 | Batch_idx: 50 |  Loss: (0.6433) | Acc: (77.88%) (2542/3264)
# Epoch: 6 | Batch_idx: 60 |  Loss: (0.6404) | Acc: (77.79%) (3037/3904)
# Epoch: 6 | Batch_idx: 70 |  Loss: (0.6497) | Acc: (77.62%) (3527/4544)
# Epoch: 6 | Batch_idx: 80 |  Loss: (0.6534) | Acc: (77.55%) (4020/5184)
# Epoch: 6 | Batch_idx: 90 |  Loss: (0.6523) | Acc: (77.47%) (4512/5824)
# Epoch: 6 | Batch_idx: 100 |  Loss: (0.6533) | Acc: (77.57%) (5014/6464)
# Epoch: 6 | Batch_idx: 110 |  Loss: (0.6455) | Acc: (77.83%) (5529/7104)
# Epoch: 6 | Batch_idx: 120 |  Loss: (0.6406) | Acc: (78.00%) (6040/7744)
# Epoch: 6 | Batch_idx: 130 |  Loss: (0.6394) | Acc: (77.99%) (6539/8384)
# Epoch: 6 | Batch_idx: 140 |  Loss: (0.6351) | Acc: (78.09%) (7047/9024)
# Epoch: 6 | Batch_idx: 150 |  Loss: (0.6356) | Acc: (78.10%) (7548/9664)
# Epoch: 6 | Batch_idx: 160 |  Loss: (0.6355) | Acc: (78.15%) (8053/10304)
# Epoch: 6 | Batch_idx: 170 |  Loss: (0.6351) | Acc: (78.09%) (8546/10944)
# Epoch: 6 | Batch_idx: 180 |  Loss: (0.6352) | Acc: (78.11%) (9048/11584)
# Epoch: 6 | Batch_idx: 190 |  Loss: (0.6328) | Acc: (78.17%) (9555/12224)
# Epoch: 6 | Batch_idx: 200 |  Loss: (0.6332) | Acc: (78.18%) (10057/12864)
# Epoch: 6 | Batch_idx: 210 |  Loss: (0.6327) | Acc: (78.18%) (10558/13504)
# Epoch: 6 | Batch_idx: 220 |  Loss: (0.6318) | Acc: (78.29%) (11074/14144)
# Epoch: 6 | Batch_idx: 230 |  Loss: (0.6323) | Acc: (78.31%) (11578/14784)
# Epoch: 6 | Batch_idx: 240 |  Loss: (0.6339) | Acc: (78.22%) (12065/15424)
# Epoch: 6 | Batch_idx: 250 |  Loss: (0.6321) | Acc: (78.31%) (12580/16064)
# Epoch: 6 | Batch_idx: 260 |  Loss: (0.6316) | Acc: (78.31%) (13081/16704)
# Epoch: 6 | Batch_idx: 270 |  Loss: (0.6336) | Acc: (78.22%) (13567/17344)
# Epoch: 6 | Batch_idx: 280 |  Loss: (0.6341) | Acc: (78.22%) (14067/17984)
# Epoch: 6 | Batch_idx: 290 |  Loss: (0.6341) | Acc: (78.28%) (14579/18624)
# Epoch: 6 | Batch_idx: 300 |  Loss: (0.6365) | Acc: (78.16%) (15056/19264)
# Epoch: 6 | Batch_idx: 310 |  Loss: (0.6342) | Acc: (78.18%) (15560/19904)
# Epoch: 6 | Batch_idx: 320 |  Loss: (0.6332) | Acc: (78.22%) (16069/20544)
# Epoch: 6 | Batch_idx: 330 |  Loss: (0.6339) | Acc: (78.24%) (16575/21184)
# Epoch: 6 | Batch_idx: 340 |  Loss: (0.6370) | Acc: (78.12%) (17048/21824)
# Epoch: 6 | Batch_idx: 350 |  Loss: (0.6358) | Acc: (78.08%) (17541/22464)
# Epoch: 6 | Batch_idx: 360 |  Loss: (0.6355) | Acc: (78.05%) (18033/23104)
# Epoch: 6 | Batch_idx: 370 |  Loss: (0.6352) | Acc: (78.03%) (18528/23744)
# Epoch: 6 | Batch_idx: 380 |  Loss: (0.6362) | Acc: (77.97%) (19013/24384)
# Epoch: 6 | Batch_idx: 390 |  Loss: (0.6353) | Acc: (78.03%) (19527/25024)
# Epoch: 6 | Batch_idx: 400 |  Loss: (0.6356) | Acc: (78.04%) (20028/25664)
# Epoch: 6 | Batch_idx: 410 |  Loss: (0.6352) | Acc: (78.07%) (20536/26304)
# Epoch: 6 | Batch_idx: 420 |  Loss: (0.6342) | Acc: (78.12%) (21050/26944)
# Epoch: 6 | Batch_idx: 430 |  Loss: (0.6358) | Acc: (78.04%) (21527/27584)
# Epoch: 6 | Batch_idx: 440 |  Loss: (0.6346) | Acc: (78.08%) (22036/28224)
# Epoch: 6 | Batch_idx: 450 |  Loss: (0.6333) | Acc: (78.09%) (22539/28864)
# Epoch: 6 | Batch_idx: 460 |  Loss: (0.6327) | Acc: (78.11%) (23047/29504)
# Epoch: 6 | Batch_idx: 470 |  Loss: (0.6323) | Acc: (78.13%) (23553/30144)
# Epoch: 6 | Batch_idx: 480 |  Loss: (0.6308) | Acc: (78.16%) (24061/30784)
# Epoch: 6 | Batch_idx: 490 |  Loss: (0.6305) | Acc: (78.17%) (24564/31424)
# Epoch: 6 | Batch_idx: 500 |  Loss: (0.6301) | Acc: (78.18%) (25069/32064)
# Epoch: 6 | Batch_idx: 510 |  Loss: (0.6291) | Acc: (78.21%) (25577/32704)
# Epoch: 6 | Batch_idx: 520 |  Loss: (0.6279) | Acc: (78.25%) (26092/33344)
# Epoch: 6 | Batch_idx: 530 |  Loss: (0.6274) | Acc: (78.27%) (26598/33984)
# Epoch: 6 | Batch_idx: 540 |  Loss: (0.6266) | Acc: (78.28%) (27102/34624)
# Epoch: 6 | Batch_idx: 550 |  Loss: (0.6270) | Acc: (78.23%) (27588/35264)
# Epoch: 6 | Batch_idx: 560 |  Loss: (0.6263) | Acc: (78.21%) (28081/35904)
# Epoch: 6 | Batch_idx: 570 |  Loss: (0.6244) | Acc: (78.27%) (28603/36544)
# Epoch: 6 | Batch_idx: 580 |  Loss: (0.6242) | Acc: (78.27%) (29103/37184)
# Epoch: 6 | Batch_idx: 590 |  Loss: (0.6240) | Acc: (78.28%) (29607/37824)
# Epoch: 6 | Batch_idx: 600 |  Loss: (0.6230) | Acc: (78.30%) (30118/38464)
# Epoch: 6 | Batch_idx: 610 |  Loss: (0.6230) | Acc: (78.31%) (30624/39104)
# Epoch: 6 | Batch_idx: 620 |  Loss: (0.6240) | Acc: (78.32%) (31127/39744)
# Epoch: 6 | Batch_idx: 630 |  Loss: (0.6243) | Acc: (78.31%) (31624/40384)
# Epoch: 6 | Batch_idx: 640 |  Loss: (0.6221) | Acc: (78.39%) (32159/41024)
# Epoch: 6 | Batch_idx: 650 |  Loss: (0.6224) | Acc: (78.38%) (32657/41664)
# Epoch: 6 | Batch_idx: 660 |  Loss: (0.6236) | Acc: (78.35%) (33144/42304)
# Epoch: 6 | Batch_idx: 670 |  Loss: (0.6236) | Acc: (78.33%) (33638/42944)
# Epoch: 6 | Batch_idx: 680 |  Loss: (0.6238) | Acc: (78.32%) (34133/43584)
# Epoch: 6 | Batch_idx: 690 |  Loss: (0.6235) | Acc: (78.33%) (34639/44224)
# Epoch: 6 | Batch_idx: 700 |  Loss: (0.6227) | Acc: (78.37%) (35158/44864)
# Epoch: 6 | Batch_idx: 710 |  Loss: (0.6218) | Acc: (78.40%) (35677/45504)
# Epoch: 6 | Batch_idx: 720 |  Loss: (0.6211) | Acc: (78.44%) (36194/46144)
# Epoch: 6 | Batch_idx: 730 |  Loss: (0.6207) | Acc: (78.43%) (36692/46784)
# Epoch: 6 | Batch_idx: 740 |  Loss: (0.6205) | Acc: (78.46%) (37211/47424)
# Epoch: 6 | Batch_idx: 750 |  Loss: (0.6210) | Acc: (78.46%) (37709/48064)
# Epoch: 6 | Batch_idx: 760 |  Loss: (0.6211) | Acc: (78.46%) (38214/48704)
# Epoch: 6 | Batch_idx: 770 |  Loss: (0.6203) | Acc: (78.48%) (38726/49344)
# Epoch: 6 | Batch_idx: 780 |  Loss: (0.6200) | Acc: (78.49%) (39230/49984)
# => saving checkpoint
# # TEST : Loss: (0.7667) | Acc: (74.83%) (7483/10000)
# Epoch: 7 | Batch_idx: 0 |  Loss: (0.5525) | Acc: (78.12%) (50/64)
# Epoch: 7 | Batch_idx: 10 |  Loss: (0.5483) | Acc: (79.55%) (560/704)
# Epoch: 7 | Batch_idx: 20 |  Loss: (0.5406) | Acc: (80.21%) (1078/1344)
# Epoch: 7 | Batch_idx: 30 |  Loss: (0.5677) | Acc: (79.94%) (1586/1984)
# Epoch: 7 | Batch_idx: 40 |  Loss: (0.5766) | Acc: (79.38%) (2083/2624)
# Epoch: 7 | Batch_idx: 50 |  Loss: (0.5752) | Acc: (79.29%) (2588/3264)
# Epoch: 7 | Batch_idx: 60 |  Loss: (0.5788) | Acc: (79.05%) (3086/3904)
# Epoch: 7 | Batch_idx: 70 |  Loss: (0.5797) | Acc: (79.34%) (3605/4544)
# Epoch: 7 | Batch_idx: 80 |  Loss: (0.5748) | Acc: (79.61%) (4127/5184)
# Epoch: 7 | Batch_idx: 90 |  Loss: (0.5737) | Acc: (79.74%) (4644/5824)
# Epoch: 7 | Batch_idx: 100 |  Loss: (0.5708) | Acc: (79.84%) (5161/6464)
# Epoch: 7 | Batch_idx: 110 |  Loss: (0.5665) | Acc: (80.10%) (5690/7104)
# Epoch: 7 | Batch_idx: 120 |  Loss: (0.5649) | Acc: (80.20%) (6211/7744)
# Epoch: 7 | Batch_idx: 130 |  Loss: (0.5623) | Acc: (80.43%) (6743/8384)
# Epoch: 7 | Batch_idx: 140 |  Loss: (0.5641) | Acc: (80.35%) (7251/9024)
# Epoch: 7 | Batch_idx: 150 |  Loss: (0.5637) | Acc: (80.32%) (7762/9664)
# Epoch: 7 | Batch_idx: 160 |  Loss: (0.5661) | Acc: (80.34%) (8278/10304)
# Epoch: 7 | Batch_idx: 170 |  Loss: (0.5647) | Acc: (80.35%) (8793/10944)
# Epoch: 7 | Batch_idx: 180 |  Loss: (0.5638) | Acc: (80.40%) (9313/11584)
# Epoch: 7 | Batch_idx: 190 |  Loss: (0.5660) | Acc: (80.41%) (9829/12224)
# Epoch: 7 | Batch_idx: 200 |  Loss: (0.5651) | Acc: (80.49%) (10354/12864)
# Epoch: 7 | Batch_idx: 210 |  Loss: (0.5633) | Acc: (80.52%) (10873/13504)
# Epoch: 7 | Batch_idx: 220 |  Loss: (0.5644) | Acc: (80.52%) (11389/14144)
# Epoch: 7 | Batch_idx: 230 |  Loss: (0.5662) | Acc: (80.42%) (11890/14784)
# Epoch: 7 | Batch_idx: 240 |  Loss: (0.5650) | Acc: (80.48%) (12413/15424)
# Epoch: 7 | Batch_idx: 250 |  Loss: (0.5663) | Acc: (80.43%) (12920/16064)
# Epoch: 7 | Batch_idx: 260 |  Loss: (0.5684) | Acc: (80.28%) (13410/16704)
# Epoch: 7 | Batch_idx: 270 |  Loss: (0.5682) | Acc: (80.26%) (13921/17344)
# Epoch: 7 | Batch_idx: 280 |  Loss: (0.5700) | Acc: (80.30%) (14441/17984)
# Epoch: 7 | Batch_idx: 290 |  Loss: (0.5683) | Acc: (80.33%) (14961/18624)
# Epoch: 7 | Batch_idx: 300 |  Loss: (0.5690) | Acc: (80.33%) (15474/19264)
# Epoch: 7 | Batch_idx: 310 |  Loss: (0.5707) | Acc: (80.26%) (15975/19904)
# Epoch: 7 | Batch_idx: 320 |  Loss: (0.5722) | Acc: (80.20%) (16476/20544)
# Epoch: 7 | Batch_idx: 330 |  Loss: (0.5709) | Acc: (80.22%) (16993/21184)
# Epoch: 7 | Batch_idx: 340 |  Loss: (0.5687) | Acc: (80.30%) (17524/21824)
# Epoch: 7 | Batch_idx: 350 |  Loss: (0.5683) | Acc: (80.33%) (18046/22464)
# Epoch: 7 | Batch_idx: 360 |  Loss: (0.5678) | Acc: (80.31%) (18554/23104)
# Epoch: 7 | Batch_idx: 370 |  Loss: (0.5679) | Acc: (80.31%) (19068/23744)
# Epoch: 7 | Batch_idx: 380 |  Loss: (0.5679) | Acc: (80.31%) (19583/24384)
# Epoch: 7 | Batch_idx: 390 |  Loss: (0.5659) | Acc: (80.37%) (20113/25024)
# Epoch: 7 | Batch_idx: 400 |  Loss: (0.5666) | Acc: (80.36%) (20623/25664)
# Epoch: 7 | Batch_idx: 410 |  Loss: (0.5658) | Acc: (80.37%) (21140/26304)
# Epoch: 7 | Batch_idx: 420 |  Loss: (0.5652) | Acc: (80.43%) (21671/26944)
# Epoch: 7 | Batch_idx: 430 |  Loss: (0.5640) | Acc: (80.48%) (22199/27584)
# Epoch: 7 | Batch_idx: 440 |  Loss: (0.5635) | Acc: (80.46%) (22710/28224)
# Epoch: 7 | Batch_idx: 450 |  Loss: (0.5635) | Acc: (80.45%) (23220/28864)
# Epoch: 7 | Batch_idx: 460 |  Loss: (0.5637) | Acc: (80.42%) (23728/29504)
# Epoch: 7 | Batch_idx: 470 |  Loss: (0.5622) | Acc: (80.47%) (24257/30144)
# Epoch: 7 | Batch_idx: 480 |  Loss: (0.5609) | Acc: (80.51%) (24783/30784)
# Epoch: 7 | Batch_idx: 490 |  Loss: (0.5596) | Acc: (80.54%) (25308/31424)
# Epoch: 7 | Batch_idx: 500 |  Loss: (0.5607) | Acc: (80.50%) (25812/32064)
# Epoch: 7 | Batch_idx: 510 |  Loss: (0.5612) | Acc: (80.47%) (26317/32704)
# Epoch: 7 | Batch_idx: 520 |  Loss: (0.5602) | Acc: (80.50%) (26842/33344)
# Epoch: 7 | Batch_idx: 530 |  Loss: (0.5587) | Acc: (80.52%) (27363/33984)
# Epoch: 7 | Batch_idx: 540 |  Loss: (0.5590) | Acc: (80.51%) (27876/34624)
# Epoch: 7 | Batch_idx: 550 |  Loss: (0.5586) | Acc: (80.52%) (28394/35264)
# Epoch: 7 | Batch_idx: 560 |  Loss: (0.5583) | Acc: (80.51%) (28906/35904)
# Epoch: 7 | Batch_idx: 570 |  Loss: (0.5580) | Acc: (80.53%) (29428/36544)
# Epoch: 7 | Batch_idx: 580 |  Loss: (0.5577) | Acc: (80.58%) (29964/37184)
# Epoch: 7 | Batch_idx: 590 |  Loss: (0.5591) | Acc: (80.54%) (30464/37824)
# Epoch: 7 | Batch_idx: 600 |  Loss: (0.5596) | Acc: (80.52%) (30973/38464)
# Epoch: 7 | Batch_idx: 610 |  Loss: (0.5601) | Acc: (80.50%) (31478/39104)
# Epoch: 7 | Batch_idx: 620 |  Loss: (0.5596) | Acc: (80.49%) (31990/39744)
# Epoch: 7 | Batch_idx: 630 |  Loss: (0.5601) | Acc: (80.45%) (32490/40384)
# Epoch: 7 | Batch_idx: 640 |  Loss: (0.5600) | Acc: (80.47%) (33011/41024)
# Epoch: 7 | Batch_idx: 650 |  Loss: (0.5596) | Acc: (80.48%) (33533/41664)
# Epoch: 7 | Batch_idx: 660 |  Loss: (0.5585) | Acc: (80.52%) (34062/42304)
# Epoch: 7 | Batch_idx: 670 |  Loss: (0.5588) | Acc: (80.49%) (34566/42944)
# Epoch: 7 | Batch_idx: 680 |  Loss: (0.5593) | Acc: (80.47%) (35074/43584)
# Epoch: 7 | Batch_idx: 690 |  Loss: (0.5595) | Acc: (80.47%) (35586/44224)
# Epoch: 7 | Batch_idx: 700 |  Loss: (0.5585) | Acc: (80.52%) (36124/44864)
# Epoch: 7 | Batch_idx: 710 |  Loss: (0.5578) | Acc: (80.56%) (36657/45504)
# Epoch: 7 | Batch_idx: 720 |  Loss: (0.5576) | Acc: (80.57%) (37179/46144)
# Epoch: 7 | Batch_idx: 730 |  Loss: (0.5585) | Acc: (80.52%) (37672/46784)
# Epoch: 7 | Batch_idx: 740 |  Loss: (0.5583) | Acc: (80.53%) (38192/47424)
# Epoch: 7 | Batch_idx: 750 |  Loss: (0.5567) | Acc: (80.61%) (38744/48064)
# Epoch: 7 | Batch_idx: 760 |  Loss: (0.5568) | Acc: (80.59%) (39252/48704)
# Epoch: 7 | Batch_idx: 770 |  Loss: (0.5558) | Acc: (80.60%) (39770/49344)
# Epoch: 7 | Batch_idx: 780 |  Loss: (0.5553) | Acc: (80.62%) (40299/49984)
# => saving checkpoint
# # TEST : Loss: (0.6308) | Acc: (78.90%) (7890/10000)
# Epoch: 8 | Batch_idx: 0 |  Loss: (0.6031) | Acc: (79.69%) (51/64)
# Epoch: 8 | Batch_idx: 10 |  Loss: (0.5584) | Acc: (79.83%) (562/704)
# Epoch: 8 | Batch_idx: 20 |  Loss: (0.5585) | Acc: (79.84%) (1073/1344)
# Epoch: 8 | Batch_idx: 30 |  Loss: (0.5411) | Acc: (80.85%) (1604/1984)
# Epoch: 8 | Batch_idx: 40 |  Loss: (0.5394) | Acc: (80.34%) (2108/2624)
# Epoch: 8 | Batch_idx: 50 |  Loss: (0.5367) | Acc: (80.64%) (2632/3264)
# Epoch: 8 | Batch_idx: 60 |  Loss: (0.5347) | Acc: (80.92%) (3159/3904)
# Epoch: 8 | Batch_idx: 70 |  Loss: (0.5316) | Acc: (81.03%) (3682/4544)
# Epoch: 8 | Batch_idx: 80 |  Loss: (0.5257) | Acc: (81.17%) (4208/5184)
# Epoch: 8 | Batch_idx: 90 |  Loss: (0.5269) | Acc: (81.11%) (4724/5824)
# Epoch: 8 | Batch_idx: 100 |  Loss: (0.5240) | Acc: (81.40%) (5262/6464)
# Epoch: 8 | Batch_idx: 110 |  Loss: (0.5243) | Acc: (81.42%) (5784/7104)
# Epoch: 8 | Batch_idx: 120 |  Loss: (0.5269) | Acc: (81.24%) (6291/7744)
# Epoch: 8 | Batch_idx: 130 |  Loss: (0.5241) | Acc: (81.32%) (6818/8384)
# Epoch: 8 | Batch_idx: 140 |  Loss: (0.5280) | Acc: (81.26%) (7333/9024)
# Epoch: 8 | Batch_idx: 150 |  Loss: (0.5254) | Acc: (81.38%) (7865/9664)
# ...
# Epoch: 162 | Batch_idx: 290 |  Loss: (0.0066) | Acc: (99.91%) (18607/18624)
# Epoch: 162 | Batch_idx: 300 |  Loss: (0.0067) | Acc: (99.90%) (19245/19264)
# Epoch: 162 | Batch_idx: 310 |  Loss: (0.0066) | Acc: (99.90%) (19885/19904)
# Epoch: 162 | Batch_idx: 320 |  Loss: (0.0067) | Acc: (99.90%) (20523/20544)
# Epoch: 162 | Batch_idx: 330 |  Loss: (0.0067) | Acc: (99.89%) (21161/21184)
# Epoch: 162 | Batch_idx: 340 |  Loss: (0.0068) | Acc: (99.89%) (21801/21824)
# Epoch: 162 | Batch_idx: 350 |  Loss: (0.0067) | Acc: (99.90%) (22441/22464)
# Epoch: 162 | Batch_idx: 360 |  Loss: (0.0067) | Acc: (99.90%) (23081/23104)
# Epoch: 162 | Batch_idx: 370 |  Loss: (0.0067) | Acc: (99.90%) (23721/23744)
# Epoch: 162 | Batch_idx: 380 |  Loss: (0.0067) | Acc: (99.91%) (24361/24384)
# Epoch: 162 | Batch_idx: 390 |  Loss: (0.0066) | Acc: (99.91%) (25001/25024)
# Epoch: 162 | Batch_idx: 400 |  Loss: (0.0067) | Acc: (99.90%) (25639/25664)
# Epoch: 162 | Batch_idx: 410 |  Loss: (0.0067) | Acc: (99.90%) (26279/26304)
# Epoch: 162 | Batch_idx: 420 |  Loss: (0.0067) | Acc: (99.91%) (26919/26944)
# Epoch: 162 | Batch_idx: 430 |  Loss: (0.0067) | Acc: (99.91%) (27558/27584)
# Epoch: 162 | Batch_idx: 440 |  Loss: (0.0066) | Acc: (99.91%) (28198/28224)
# Epoch: 162 | Batch_idx: 450 |  Loss: (0.0067) | Acc: (99.91%) (28838/28864)
# Epoch: 162 | Batch_idx: 460 |  Loss: (0.0066) | Acc: (99.91%) (29478/29504)
# Epoch: 162 | Batch_idx: 470 |  Loss: (0.0066) | Acc: (99.91%) (30118/30144)
# Epoch: 162 | Batch_idx: 480 |  Loss: (0.0066) | Acc: (99.92%) (30758/30784)
# Epoch: 162 | Batch_idx: 490 |  Loss: (0.0065) | Acc: (99.91%) (31397/31424)
# Epoch: 162 | Batch_idx: 500 |  Loss: (0.0065) | Acc: (99.92%) (32037/32064)
# Epoch: 162 | Batch_idx: 510 |  Loss: (0.0065) | Acc: (99.91%) (32676/32704)
# Epoch: 162 | Batch_idx: 520 |  Loss: (0.0065) | Acc: (99.91%) (33315/33344)
# Epoch: 162 | Batch_idx: 530 |  Loss: (0.0065) | Acc: (99.91%) (33954/33984)
# Epoch: 162 | Batch_idx: 540 |  Loss: (0.0064) | Acc: (99.91%) (34594/34624)
# Epoch: 162 | Batch_idx: 550 |  Loss: (0.0065) | Acc: (99.91%) (35233/35264)
# Epoch: 162 | Batch_idx: 560 |  Loss: (0.0065) | Acc: (99.91%) (35873/35904)
# Epoch: 162 | Batch_idx: 570 |  Loss: (0.0065) | Acc: (99.91%) (36512/36544)
# Epoch: 162 | Batch_idx: 580 |  Loss: (0.0065) | Acc: (99.91%) (37151/37184)
# Epoch: 162 | Batch_idx: 590 |  Loss: (0.0065) | Acc: (99.91%) (37790/37824)
# Epoch: 162 | Batch_idx: 600 |  Loss: (0.0065) | Acc: (99.91%) (38430/38464)
# Epoch: 162 | Batch_idx: 610 |  Loss: (0.0065) | Acc: (99.91%) (39068/39104)
# Epoch: 162 | Batch_idx: 620 |  Loss: (0.0065) | Acc: (99.91%) (39708/39744)
# Epoch: 162 | Batch_idx: 630 |  Loss: (0.0065) | Acc: (99.91%) (40347/40384)
# Epoch: 162 | Batch_idx: 640 |  Loss: (0.0065) | Acc: (99.91%) (40987/41024)
# Epoch: 162 | Batch_idx: 650 |  Loss: (0.0065) | Acc: (99.91%) (41627/41664)
# Epoch: 162 | Batch_idx: 660 |  Loss: (0.0065) | Acc: (99.91%) (42266/42304)
# Epoch: 162 | Batch_idx: 670 |  Loss: (0.0065) | Acc: (99.91%) (42905/42944)
# Epoch: 162 | Batch_idx: 680 |  Loss: (0.0065) | Acc: (99.91%) (43543/43584)
# Epoch: 162 | Batch_idx: 690 |  Loss: (0.0065) | Acc: (99.91%) (44183/44224)
# Epoch: 162 | Batch_idx: 700 |  Loss: (0.0065) | Acc: (99.91%) (44822/44864)
# Epoch: 162 | Batch_idx: 710 |  Loss: (0.0065) | Acc: (99.91%) (45462/45504)
# Epoch: 162 | Batch_idx: 720 |  Loss: (0.0065) | Acc: (99.91%) (46102/46144)
# Epoch: 162 | Batch_idx: 730 |  Loss: (0.0065) | Acc: (99.91%) (46742/46784)
# Epoch: 162 | Batch_idx: 740 |  Loss: (0.0064) | Acc: (99.91%) (47382/47424)
# Epoch: 162 | Batch_idx: 750 |  Loss: (0.0064) | Acc: (99.91%) (48022/48064)
# Epoch: 162 | Batch_idx: 760 |  Loss: (0.0065) | Acc: (99.91%) (48659/48704)
# Epoch: 162 | Batch_idx: 770 |  Loss: (0.0065) | Acc: (99.91%) (49299/49344)
# Epoch: 162 | Batch_idx: 780 |  Loss: (0.0065) | Acc: (99.91%) (49938/49984)
# => saving checkpoint
# # TEST : Loss: (0.2574) | Acc: (93.48%) (9348/10000)
# Epoch: 163 | Batch_idx: 0 |  Loss: (0.0030) | Acc: (100.00%) (64/64)
# Epoch: 163 | Batch_idx: 10 |  Loss: (0.0061) | Acc: (100.00%) (704/704)
# Epoch: 163 | Batch_idx: 20 |  Loss: (0.0057) | Acc: (100.00%) (1344/1344)
# Epoch: 163 | Batch_idx: 30 |  Loss: (0.0061) | Acc: (100.00%) (1984/1984)
# Epoch: 163 | Batch_idx: 40 |  Loss: (0.0060) | Acc: (100.00%) (2624/2624)
# Epoch: 163 | Batch_idx: 50 |  Loss: (0.0063) | Acc: (99.97%) (3263/3264)
# Epoch: 163 | Batch_idx: 60 |  Loss: (0.0061) | Acc: (99.97%) (3903/3904)
# Epoch: 163 | Batch_idx: 70 |  Loss: (0.0058) | Acc: (99.98%) (4543/4544)
# Epoch: 163 | Batch_idx: 80 |  Loss: (0.0062) | Acc: (99.96%) (5182/5184)
# Epoch: 163 | Batch_idx: 90 |  Loss: (0.0061) | Acc: (99.97%) (5822/5824)
# Epoch: 163 | Batch_idx: 100 |  Loss: (0.0058) | Acc: (99.97%) (6462/6464)
# Epoch: 163 | Batch_idx: 110 |  Loss: (0.0062) | Acc: (99.96%) (7101/7104)
# Epoch: 163 | Batch_idx: 120 |  Loss: (0.0064) | Acc: (99.94%) (7739/7744)
# Epoch: 163 | Batch_idx: 130 |  Loss: (0.0063) | Acc: (99.93%) (8378/8384)
# Epoch: 163 | Batch_idx: 140 |  Loss: (0.0062) | Acc: (99.93%) (9018/9024)
# Epoch: 163 | Batch_idx: 150 |  Loss: (0.0064) | Acc: (99.93%) (9657/9664)
# Epoch: 163 | Batch_idx: 160 |  Loss: (0.0065) | Acc: (99.92%) (10296/10304)
# Epoch: 163 | Batch_idx: 170 |  Loss: (0.0067) | Acc: (99.92%) (10935/10944)
# Epoch: 163 | Batch_idx: 180 |  Loss: (0.0067) | Acc: (99.92%) (11575/11584)
# Epoch: 163 | Batch_idx: 190 |  Loss: (0.0066) | Acc: (99.93%) (12215/12224)
# Epoch: 163 | Batch_idx: 200 |  Loss: (0.0065) | Acc: (99.93%) (12855/12864)
# Epoch: 163 | Batch_idx: 210 |  Loss: (0.0068) | Acc: (99.92%) (13493/13504)
# Epoch: 163 | Batch_idx: 220 |  Loss: (0.0067) | Acc: (99.92%) (14133/14144)
# Epoch: 163 | Batch_idx: 230 |  Loss: (0.0067) | Acc: (99.93%) (14773/14784)
# Epoch: 163 | Batch_idx: 240 |  Loss: (0.0066) | Acc: (99.93%) (15413/15424)
# Epoch: 163 | Batch_idx: 250 |  Loss: (0.0065) | Acc: (99.93%) (16053/16064)
# Epoch: 163 | Batch_idx: 260 |  Loss: (0.0065) | Acc: (99.93%) (16693/16704)
# Epoch: 163 | Batch_idx: 270 |  Loss: (0.0065) | Acc: (99.94%) (17333/17344)
# Epoch: 163 | Batch_idx: 280 |  Loss: (0.0063) | Acc: (99.94%) (17973/17984)
# Epoch: 163 | Batch_idx: 290 |  Loss: (0.0063) | Acc: (99.94%) (18613/18624)
# Epoch: 163 | Batch_idx: 300 |  Loss: (0.0063) | Acc: (99.94%) (19253/19264)
# Epoch: 163 | Batch_idx: 310 |  Loss: (0.0062) | Acc: (99.94%) (19893/19904)
# Epoch: 163 | Batch_idx: 320 |  Loss: (0.0062) | Acc: (99.95%) (20533/20544)
# Epoch: 163 | Batch_idx: 330 |  Loss: (0.0062) | Acc: (99.95%) (21173/21184)
# Epoch: 163 | Batch_idx: 340 |  Loss: (0.0062) | Acc: (99.95%) (21812/21824)
# Epoch: 163 | Batch_idx: 350 |  Loss: (0.0061) | Acc: (99.95%) (22452/22464)
# Epoch: 163 | Batch_idx: 360 |  Loss: (0.0061) | Acc: (99.95%) (23092/23104)
# Epoch: 163 | Batch_idx: 370 |  Loss: (0.0061) | Acc: (99.95%) (23731/23744)
# Epoch: 163 | Batch_idx: 380 |  Loss: (0.0060) | Acc: (99.95%) (24371/24384)
# Epoch: 163 | Batch_idx: 390 |  Loss: (0.0060) | Acc: (99.95%) (25011/25024)
# Epoch: 163 | Batch_idx: 400 |  Loss: (0.0060) | Acc: (99.95%) (25650/25664)
# Epoch: 163 | Batch_idx: 410 |  Loss: (0.0060) | Acc: (99.95%) (26290/26304)
# Epoch: 163 | Batch_idx: 420 |  Loss: (0.0061) | Acc: (99.94%) (26928/26944)
# Epoch: 163 | Batch_idx: 430 |  Loss: (0.0061) | Acc: (99.93%) (27566/27584)
# Epoch: 163 | Batch_idx: 440 |  Loss: (0.0061) | Acc: (99.94%) (28206/28224)
# Epoch: 163 | Batch_idx: 450 |  Loss: (0.0060) | Acc: (99.94%) (28846/28864)
# Epoch: 163 | Batch_idx: 460 |  Loss: (0.0060) | Acc: (99.94%) (29485/29504)
# Epoch: 163 | Batch_idx: 470 |  Loss: (0.0060) | Acc: (99.94%) (30125/30144)
# Epoch: 163 | Batch_idx: 480 |  Loss: (0.0061) | Acc: (99.94%) (30765/30784)
# Epoch: 163 | Batch_idx: 490 |  Loss: (0.0060) | Acc: (99.94%) (31405/31424)
# Epoch: 163 | Batch_idx: 500 |  Loss: (0.0060) | Acc: (99.94%) (32045/32064)
# Epoch: 163 | Batch_idx: 510 |  Loss: (0.0061) | Acc: (99.94%) (32684/32704)
# Epoch: 163 | Batch_idx: 520 |  Loss: (0.0062) | Acc: (99.93%) (33322/33344)
# Epoch: 163 | Batch_idx: 530 |  Loss: (0.0062) | Acc: (99.94%) (33962/33984)
# Epoch: 163 | Batch_idx: 540 |  Loss: (0.0062) | Acc: (99.94%) (34602/34624)
# Epoch: 163 | Batch_idx: 550 |  Loss: (0.0062) | Acc: (99.94%) (35242/35264)
# Epoch: 163 | Batch_idx: 560 |  Loss: (0.0062) | Acc: (99.94%) (35882/35904)
# Epoch: 163 | Batch_idx: 570 |  Loss: (0.0061) | Acc: (99.94%) (36522/36544)
# Epoch: 163 | Batch_idx: 580 |  Loss: (0.0061) | Acc: (99.94%) (37161/37184)
# Epoch: 163 | Batch_idx: 590 |  Loss: (0.0062) | Acc: (99.94%) (37800/37824)
# Epoch: 163 | Batch_idx: 600 |  Loss: (0.0062) | Acc: (99.93%) (38438/38464)
# Epoch: 163 | Batch_idx: 610 |  Loss: (0.0062) | Acc: (99.93%) (39077/39104)
# Epoch: 163 | Batch_idx: 620 |  Loss: (0.0062) | Acc: (99.93%) (39717/39744)
# Epoch: 163 | Batch_idx: 630 |  Loss: (0.0062) | Acc: (99.93%) (40357/40384)
# Epoch: 163 | Batch_idx: 640 |  Loss: (0.0061) | Acc: (99.93%) (40997/41024)
# Epoch: 163 | Batch_idx: 650 |  Loss: (0.0062) | Acc: (99.93%) (41636/41664)
# Epoch: 163 | Batch_idx: 660 |  Loss: (0.0061) | Acc: (99.93%) (42276/42304)
# Epoch: 163 | Batch_idx: 670 |  Loss: (0.0061) | Acc: (99.93%) (42916/42944)
# Epoch: 163 | Batch_idx: 680 |  Loss: (0.0061) | Acc: (99.94%) (43556/43584)
# Epoch: 163 | Batch_idx: 690 |  Loss: (0.0062) | Acc: (99.93%) (44194/44224)
# Epoch: 163 | Batch_idx: 700 |  Loss: (0.0062) | Acc: (99.93%) (44834/44864)
# Epoch: 163 | Batch_idx: 710 |  Loss: (0.0062) | Acc: (99.93%) (45473/45504)
# Epoch: 163 | Batch_idx: 720 |  Loss: (0.0062) | Acc: (99.93%) (46112/46144)
# Epoch: 163 | Batch_idx: 730 |  Loss: (0.0062) | Acc: (99.93%) (46751/46784)
# Epoch: 163 | Batch_idx: 740 |  Loss: (0.0062) | Acc: (99.93%) (47391/47424)
# Epoch: 163 | Batch_idx: 750 |  Loss: (0.0062) | Acc: (99.93%) (48031/48064)
# Epoch: 163 | Batch_idx: 760 |  Loss: (0.0063) | Acc: (99.93%) (48669/48704)
# Epoch: 163 | Batch_idx: 770 |  Loss: (0.0062) | Acc: (99.93%) (49309/49344)
# Epoch: 163 | Batch_idx: 780 |  Loss: (0.0063) | Acc: (99.93%) (49948/49984)
# => saving checkpoint
# # TEST : Loss: (0.2555) | Acc: (93.59%) (9359/10000)
# Epoch: 164 | Batch_idx: 0 |  Loss: (0.0073) | Acc: (100.00%) (64/64)
# Epoch: 164 | Batch_idx: 10 |  Loss: (0.0064) | Acc: (99.86%) (703/704)
# Epoch: 164 | Batch_idx: 20 |  Loss: (0.0065) | Acc: (99.85%) (1342/1344)
# Epoch: 164 | Batch_idx: 30 |  Loss: (0.0057) | Acc: (99.90%) (1982/1984)
# Epoch: 164 | Batch_idx: 40 |  Loss: (0.0056) | Acc: (99.89%) (2621/2624)
# Epoch: 164 | Batch_idx: 50 |  Loss: (0.0054) | Acc: (99.91%) (3261/3264)
# Epoch: 164 | Batch_idx: 60 |  Loss: (0.0055) | Acc: (99.92%) (3901/3904)
# Epoch: 164 | Batch_idx: 70 |  Loss: (0.0056) | Acc: (99.93%) (4541/4544)
# Epoch: 164 | Batch_idx: 80 |  Loss: (0.0055) | Acc: (99.94%) (5181/5184)
# Epoch: 164 | Batch_idx: 90 |  Loss: (0.0055) | Acc: (99.93%) (5820/5824)
# Epoch: 164 | Batch_idx: 100 |  Loss: (0.0058) | Acc: (99.92%) (6459/6464)
# Epoch: 164 | Batch_idx: 110 |  Loss: (0.0057) | Acc: (99.93%) (7099/7104)
# Epoch: 164 | Batch_idx: 120 |  Loss: (0.0055) | Acc: (99.94%) (7739/7744)
# Epoch: 164 | Batch_idx: 130 |  Loss: (0.0057) | Acc: (99.93%) (8378/8384)
# Epoch: 164 | Batch_idx: 140 |  Loss: (0.0057) | Acc: (99.93%) (9018/9024)
# Epoch: 164 | Batch_idx: 150 |  Loss: (0.0057) | Acc: (99.94%) (9658/9664)
# Epoch: 164 | Batch_idx: 160 |  Loss: (0.0060) | Acc: (99.91%) (10295/10304)
# Epoch: 164 | Batch_idx: 170 |  Loss: (0.0059) | Acc: (99.92%) (10935/10944)
# Epoch: 164 | Batch_idx: 180 |  Loss: (0.0059) | Acc: (99.91%) (11574/11584)
# Epoch: 164 | Batch_idx: 190 |  Loss: (0.0060) | Acc: (99.91%) (12213/12224)
# Epoch: 164 | Batch_idx: 200 |  Loss: (0.0060) | Acc: (99.91%) (12852/12864)
# Epoch: 164 | Batch_idx: 210 |  Loss: (0.0061) | Acc: (99.91%) (13492/13504)
# Epoch: 164 | Batch_idx: 220 |  Loss: (0.0061) | Acc: (99.91%) (14131/14144)
# Epoch: 164 | Batch_idx: 230 |  Loss: (0.0063) | Acc: (99.90%) (14769/14784)
# Epoch: 164 | Batch_idx: 240 |  Loss: (0.0062) | Acc: (99.90%) (15409/15424)
# Epoch: 164 | Batch_idx: 250 |  Loss: (0.0062) | Acc: (99.91%) (16049/16064)
# Epoch: 164 | Batch_idx: 260 |  Loss: (0.0062) | Acc: (99.91%) (16689/16704)
# Epoch: 164 | Batch_idx: 270 |  Loss: (0.0061) | Acc: (99.91%) (17329/17344)
# Epoch: 164 | Batch_idx: 280 |  Loss: (0.0061) | Acc: (99.92%) (17969/17984)
# Epoch: 164 | Batch_idx: 290 |  Loss: (0.0061) | Acc: (99.91%) (18608/18624)
# Epoch: 164 | Batch_idx: 300 |  Loss: (0.0061) | Acc: (99.91%) (19247/19264)
# Epoch: 164 | Batch_idx: 310 |  Loss: (0.0061) | Acc: (99.90%) (19885/19904)
# Epoch: 164 | Batch_idx: 320 |  Loss: (0.0061) | Acc: (99.91%) (20525/20544)
# Epoch: 164 | Batch_idx: 330 |  Loss: (0.0061) | Acc: (99.91%) (21164/21184)
# Epoch: 164 | Batch_idx: 340 |  Loss: (0.0061) | Acc: (99.91%) (21804/21824)
# Epoch: 164 | Batch_idx: 350 |  Loss: (0.0062) | Acc: (99.91%) (22443/22464)
# Epoch: 164 | Batch_idx: 360 |  Loss: (0.0062) | Acc: (99.90%) (23082/23104)
# Epoch: 164 | Batch_idx: 370 |  Loss: (0.0062) | Acc: (99.90%) (23721/23744)
# Epoch: 164 | Batch_idx: 380 |  Loss: (0.0061) | Acc: (99.91%) (24361/24384)
# Epoch: 164 | Batch_idx: 390 |  Loss: (0.0061) | Acc: (99.90%) (25000/25024)
# Epoch: 164 | Batch_idx: 400 |  Loss: (0.0061) | Acc: (99.91%) (25640/25664)
# Epoch: 164 | Batch_idx: 410 |  Loss: (0.0061) | Acc: (99.91%) (26280/26304)
# Epoch: 164 | Batch_idx: 420 |  Loss: (0.0061) | Acc: (99.91%) (26919/26944)
# Epoch: 164 | Batch_idx: 430 |  Loss: (0.0062) | Acc: (99.90%) (27556/27584)
# Epoch: 164 | Batch_idx: 440 |  Loss: (0.0062) | Acc: (99.89%) (28194/28224)
# Epoch: 164 | Batch_idx: 450 |  Loss: (0.0062) | Acc: (99.90%) (28834/28864)
# Epoch: 164 | Batch_idx: 460 |  Loss: (0.0062) | Acc: (99.90%) (29474/29504)
# Epoch: 164 | Batch_idx: 470 |  Loss: (0.0061) | Acc: (99.90%) (30114/30144)
# Epoch: 164 | Batch_idx: 480 |  Loss: (0.0062) | Acc: (99.90%) (30752/30784)
# Epoch: 164 | Batch_idx: 490 |  Loss: (0.0063) | Acc: (99.90%) (31392/31424)
# Epoch: 164 | Batch_idx: 500 |  Loss: (0.0063) | Acc: (99.90%) (32032/32064)
# Epoch: 164 | Batch_idx: 510 |  Loss: (0.0063) | Acc: (99.90%) (32671/32704)
# Epoch: 164 | Batch_idx: 520 |  Loss: (0.0063) | Acc: (99.90%) (33311/33344)
# Epoch: 164 | Batch_idx: 530 |  Loss: (0.0063) | Acc: (99.90%) (33951/33984)
# Epoch: 164 | Batch_idx: 540 |  Loss: (0.0063) | Acc: (99.90%) (34591/34624)
# Epoch: 164 | Batch_idx: 550 |  Loss: (0.0063) | Acc: (99.91%) (35231/35264)
# Epoch: 164 | Batch_idx: 560 |  Loss: (0.0063) | Acc: (99.90%) (35869/35904)
# Epoch: 164 | Batch_idx: 570 |  Loss: (0.0062) | Acc: (99.90%) (36509/36544)
# Epoch: 164 | Batch_idx: 580 |  Loss: (0.0062) | Acc: (99.91%) (37149/37184)
# Epoch: 164 | Batch_idx: 590 |  Loss: (0.0062) | Acc: (99.91%) (37789/37824)
# Epoch: 164 | Batch_idx: 600 |  Loss: (0.0062) | Acc: (99.91%) (38429/38464)
# Epoch: 164 | Batch_idx: 610 |  Loss: (0.0062) | Acc: (99.91%) (39068/39104)
# Epoch: 164 | Batch_idx: 620 |  Loss: (0.0062) | Acc: (99.91%) (39708/39744)
# Epoch: 164 | Batch_idx: 630 |  Loss: (0.0061) | Acc: (99.91%) (40348/40384)
# Epoch: 164 | Batch_idx: 640 |  Loss: (0.0061) | Acc: (99.91%) (40988/41024)
# Epoch: 164 | Batch_idx: 650 |  Loss: (0.0062) | Acc: (99.91%) (41627/41664)
# Epoch: 164 | Batch_idx: 660 |  Loss: (0.0062) | Acc: (99.91%) (42267/42304)
# Epoch: 164 | Batch_idx: 670 |  Loss: (0.0062) | Acc: (99.91%) (42905/42944)
# Epoch: 164 | Batch_idx: 680 |  Loss: (0.0062) | Acc: (99.91%) (43545/43584)
# Epoch: 164 | Batch_idx: 690 |  Loss: (0.0062) | Acc: (99.91%) (44185/44224)
# Epoch: 164 | Batch_idx: 700 |  Loss: (0.0062) | Acc: (99.91%) (44824/44864)
# Epoch: 164 | Batch_idx: 710 |  Loss: (0.0062) | Acc: (99.91%) (45464/45504)
# Epoch: 164 | Batch_idx: 720 |  Loss: (0.0062) | Acc: (99.91%) (46104/46144)
# Epoch: 164 | Batch_idx: 730 |  Loss: (0.0061) | Acc: (99.91%) (46744/46784)
# Epoch: 164 | Batch_idx: 740 |  Loss: (0.0062) | Acc: (99.91%) (47383/47424)
# Epoch: 164 | Batch_idx: 750 |  Loss: (0.0062) | Acc: (99.91%) (48022/48064)
# Epoch: 164 | Batch_idx: 760 |  Loss: (0.0061) | Acc: (99.91%) (48662/48704)
# Epoch: 164 | Batch_idx: 770 |  Loss: (0.0062) | Acc: (99.91%) (49301/49344)
# Epoch: 164 | Batch_idx: 780 |  Loss: (0.0061) | Acc: (99.91%) (49941/49984)
# => saving checkpoint
# # TEST : Loss: (0.2581) | Acc: (93.58%) (9358/10000)
# 1 hours 47 mins 35 secs for training
